# %% [markdown]
# <b>CNN for time series classification, example 2, Delhi Climate data</b>

# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# if your Jupyter kernel crashes during this code, use this setting
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# %%
df1 = pd.read_csv("DailyDelhiClimateTrain.csv")
df2 = pd.read_csv("DailyDelhiClimateTest.csv")

# combine datasets and reset the index (so that we 
# have a sequence number alongside the timestamp))
df = pd.concat([df1, df2])
df = df.reset_index()

# %%
df.head()
# Out:
#    index        date   meantemp   humidity  wind_speed  meanpressure
# 0      0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1      1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2      2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3      3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4      4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
df.describe()
# Out:
#              index     meantemp     humidity   wind_speed  meanpressure
# count  1576.000000  1576.000000  1576.000000  1576.000000   1576.000000
# mean    681.746193    25.221918    60.445229     6.899262   1010.593178
# std     442.630431     7.345014    16.979994     4.510725    175.242704
# min       0.000000     6.000000    13.428571     0.000000     -3.041667
# 25%     279.750000    18.500000    49.750000     3.700000   1001.875000
# 50%     673.500000    27.166667    62.440476     6.363571   1009.055556
# 75%    1067.250000    31.142857    72.125000     9.262500   1015.200000
# max    1461.000000    38.714286   100.000000    42.220000   7679.333333

# %%
# this dataformat is not suitable yet for CNN time series classification
# because each point is separate in the dataset

# we have to process the data into smaller chunks -> for example
# chunks of 50 points at a time

# we are going to select meantemp and wind_speed as our target outputs
df = df.drop(['humidity', 'meanpressure'], axis=1)

# %%
df.head()
# Out:
#    index        date   meantemp  wind_speed
# 0      0  2013-01-01  10.000000    0.000000
# 1      1  2013-01-02   7.400000    2.980000
# 2      2  2013-01-03   7.166667    4.633333
# 3      3  2013-01-04   8.666667    1.233333
# 4      4  2013-01-05   6.000000    3.700000

# %% [markdown]
# <b>Scale the values (important in CNN)</b>

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# cale only relevant variables
num_cols = ['meantemp', 'wind_speed']
df[num_cols] = scaler.fit_transform(df[num_cols])

# %%
df.head()
# Out:
#    index        date  meantemp  wind_speed
# 0      0  2013-01-01  0.122271    0.000000
# 1      1  2013-01-02  0.042795    0.070583
# 2      2  2013-01-03  0.035662    0.109743
# 3      3  2013-01-04  0.081514    0.029212
# 4      4  2013-01-05  0.000000    0.087636

# %%
# instead of the date-column and old index,
# let's use a sequence number
# starting from 1 until the final row
df['sequence'] = df.index + 1
df = df.drop(['date', 'index'], axis=1)

# %%
df.tail()
# Out:
#       meantemp  wind_speed  sequence
# 1571  0.871179    0.131750      1572
# 1572  0.863537    0.164910      1573
# 1573  0.822271    0.210564      1574
# 1574  0.821507    0.235966      1575
# 1575  0.794760    0.287947      1576

# %% [markdown]
# <b>Split the DataFrame into timesteps</b>

# %%
from numpy.lib.stride_tricks import sliding_window_view

timestep_size = 50

# separate the output variables
meantemp = df['meantemp'].values
wind_speed = df['wind_speed'].values

# generate timestep windows for each signal
meantemp_windows = sliding_window_view(meantemp, window_shape=timestep_size)
wind_speed_windows = sliding_window_view(wind_speed, window_shape=timestep_size)

# combine into X and y
# use vstack to combine temperatures and wind speeds back together
X = np.vstack((meantemp_windows, wind_speed_windows))

# generate zeroes and ones for the output categories
# 0 = meantemp
# 1 = wind_speed
y = np.array([0] * len(meantemp_windows) + [1] * len(wind_speed_windows))

print("X:", X.shape)
print("y:", y.shape)
# Out:
# X: (3054, 50)
# y: (3054,)

# %%
from sklearn.utils import shuffle

# shuffle the data
X, y = shuffle(X, y, random_state=42)

# %%
test_signal_index = 2

c_x_train = X[y == 0]
plt.plot(c_x_train[test_signal_index], label="Class 0: meantemp")

c_x_train = X[y == 1]
plt.plot(c_x_train[test_signal_index], label="Class 1: wind_speed")
plt.legend()

# %% [markdown]
# <b>Finally we can do the train/test split</b>

# %%
# define the cutoff point
train_size = 0.7
splitter = int(len(X) * train_size)

# split to train/test
x_train = X[0:splitter]
x_test = X[splitter:]
y_train = y[0:splitter]
y_test = y[splitter:]

# %%
print(len(x_train))
print(len(x_test))
print(len(y_train))
print(len(y_test))
# Out:
# 2137
# 917
# 2137
# 917

# %%
x_train
# Out:
# array([[0.73362445, 0.6768559 , 0.63755459, ..., 0.35534934, 0.33624454,
#         0.32478166],
#        [0.82532751, 0.79475983, 0.77565502, ..., 0.7680131 , 0.74672489,
#         0.77565502],
#        [0.7802804 , 0.83197266, 0.89469264, ..., 0.81195415, 0.77947598,
#         0.7489083 ],
#        ...,
#        [0.72925764, 0.7860262 , 0.80349345, ..., 0.77947598, 0.83296943,
#         0.8202329 ],
#        [0.50436681, 0.70815138, 0.54512373, ..., 0.81386463, 0.81768559,
#         0.82150655],
#        [0.28511369, 0.35084083, 0.57614874, ..., 0.14803411, 0.4275225 ,
#         0.13707958]])

# %%
# convert the data into the required CNN -format
# usuallu the easiest approach is to modify
# your own data to follow the data format used by another example 
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# %%
x_train
# Out:
# array([[[0.73362445],
#         [0.6768559 ],
#         [0.63755459],
#         ...,
#         [0.35534934],
#         [0.33624454],
#         [0.32478166]],
#
#        [[0.82532751],
#         [0.79475983],
#         [0.77565502],
#         ...,
#         [0.7680131 ],
#         [0.74672489],
#         [0.77565502]],
#
#        [[0.7802804 ],
#         [0.83197266],
#         [0.89469264],
#         ...,
#         [0.81195415],
#         [0.77947598],
#         [0.7489083 ]],
#
#        ...,
#
#        [[0.72925764],
#         [0.7860262 ],
#         [0.80349345],
#         ...,
#         [0.77947598],
#         [0.83296943],
#         [0.8202329 ]],
#
#        [[0.50436681],
#         [0.70815138],
#         [0.54512373],
#         ...,
#         [0.81386463],
#         [0.81768559],
#         [0.82150655]],
#
#        [[0.28511369],
#         [0.35084083],
#         [0.57614874],
#         ...,
#         [0.14803411],
#         [0.4275225 ],
#         [0.13707958]]])

# %%
class_names = np.array(["meantemp", "wind_speed"])
num_classes = len(class_names)
classes = [0, 1]

def make_model(input_shape):
    model = keras.Sequential(
        [
            # input layer
            keras.layers.Input(input_shape),

            # convolutional layer 1 (we usually have 1-3 convolutional layers
            # depending how much and how complex the data is) -> "model capacity / decision space"
            keras.layers.Conv1D(filters=64, kernel_size=3, padding="same"),
            keras.layers.BatchNormalization(),
            keras.layers.ReLU(),

            # pooling + flatten (adapter from convolutional to dense)
            # flattening is done only once after the final convolutional layer 
            # and before the Dense-network
            keras.layers.GlobalAveragePooling1D(),
            keras.layers.Flatten(),

            # neural network Dense-tail
            keras.layers.Dense(64, activation="relu"),

            # output layer
            keras.layers.Dense(num_classes, activation="softmax")
        ]
    )

    return model


model = make_model(input_shape=x_train.shape[1:])

# pip install pydot -> restart Kernel
# keras.utils.plot_model(model, show_shapes=True)

# %%
epochs = 500
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model2.keras", save_best_only=True, monitor="val_loss"
    ),

]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.4433 - sparse_categorical_accuracy: 0.7704 - val_loss: 0.6398 - val_sparse_categorical_accuracy: 0.4790
# Epoch 2/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2266 - sparse_categorical_accuracy: 0.9111 - val_loss: 0.6300 - val_sparse_categorical_accuracy: 0.4790
# Epoch 3/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1737 - sparse_categorical_accuracy: 0.9279 - val_loss: 0.6421 - val_sparse_categorical_accuracy: 0.4790
# Epoch 4/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1672 - sparse_categorical_accuracy: 0.9364 - val_loss: 0.6577 - val_sparse_categorical_accuracy: 0.4930
# Epoch 5/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1576 - sparse_categorical_accuracy: 0.9407 - val_loss: 0.6294 - val_sparse_categorical_accuracy: 0.5164
# Epoch 6/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1389 - sparse_categorical_accuracy: 0.9468 - val_loss: 0.5583 - val_sparse_categorical_accuracy: 0.5724
# Epoch 7/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1129 - sparse_categorical_accuracy: 0.9523 - val_loss: 0.3994 - val_sparse_categorical_accuracy: 0.7477
# Epoch 8/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1199 - sparse_categorical_accuracy: 0.9537 - val_loss: 0.3431 - val_sparse_categorical_accuracy: 0.8201
# Epoch 9/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1072 - sparse_categorical_accuracy: 0.9707 - val_loss: 0.1965 - val_sparse_categorical_accuracy: 0.9509
# Epoch 10/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0774 - sparse_categorical_accuracy: 0.9673 - val_loss: 0.1588 - val_sparse_categorical_accuracy: 0.9836
# Epoch 11/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0847 - sparse_categorical_accuracy: 0.9705 - val_loss: 0.1557 - val_sparse_categorical_accuracy: 1.0000
# Epoch 12/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0709 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.0960 - val_sparse_categorical_accuracy: 0.9977
# Epoch 13/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0531 - sparse_categorical_accuracy: 0.9754 - val_loss: 0.0819 - val_sparse_categorical_accuracy: 1.0000
# Epoch 14/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - sparse_categorical_accuracy: 0.9832 - val_loss: 0.0401 - val_sparse_categorical_accuracy: 0.9930
# Epoch 15/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0315 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.0346 - val_sparse_categorical_accuracy: 0.9907
# Epoch 16/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0499 - sparse_categorical_accuracy: 0.9789 - val_loss: 0.0275 - val_sparse_categorical_accuracy: 0.9907
# Epoch 17/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0394 - sparse_categorical_accuracy: 0.9815 - val_loss: 0.0267 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0267 - sparse_categorical_accuracy: 0.9902 - val_loss: 0.0245 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0231 - sparse_categorical_accuracy: 0.9959 - val_loss: 0.0194 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0389 - sparse_categorical_accuracy: 0.9878 - val_loss: 0.0365 - val_sparse_categorical_accuracy: 0.9977
# Epoch 21/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0195 - sparse_categorical_accuracy: 0.9939 - val_loss: 0.0224 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0404 - sparse_categorical_accuracy: 0.9868 - val_loss: 0.0169 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0436 - sparse_categorical_accuracy: 0.9839 - val_loss: 0.0315 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0275 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.0356 - val_sparse_categorical_accuracy: 0.9953
# Epoch 25/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0301 - sparse_categorical_accuracy: 0.9917 - val_loss: 0.2121 - val_sparse_categorical_accuracy: 0.9136
# Epoch 26/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0186 - sparse_categorical_accuracy: 0.9966 - val_loss: 0.0408 - val_sparse_categorical_accuracy: 0.9907
# Epoch 27/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0152 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0148 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0143 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0551 - val_sparse_categorical_accuracy: 0.9860
# Epoch 29/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.3695 - val_sparse_categorical_accuracy: 0.8364
# Epoch 30/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - sparse_categorical_accuracy: 0.9941 - val_loss: 1.6210 - val_sparse_categorical_accuracy: 0.5701
# Epoch 31/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0226 - sparse_categorical_accuracy: 0.9912 - val_loss: 1.5924 - val_sparse_categorical_accuracy: 0.5701
# Epoch 32/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0182 - sparse_categorical_accuracy: 0.9961 - val_loss: 1.2408 - val_sparse_categorical_accuracy: 0.5935
# Epoch 33/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0173 - sparse_categorical_accuracy: 0.9966 - val_loss: 0.6846 - val_sparse_categorical_accuracy: 0.7173
# Epoch 34/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0162 - sparse_categorical_accuracy: 0.9967 - val_loss: 1.4949 - val_sparse_categorical_accuracy: 0.5748
# Epoch 35/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0241 - sparse_categorical_accuracy: 0.9885 - val_loss: 1.9368 - val_sparse_categorical_accuracy: 0.5537
# Epoch 36/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0128 - sparse_categorical_accuracy: 0.9963 - val_loss: 1.6130 - val_sparse_categorical_accuracy: 0.5748
# Epoch 37/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0131 - sparse_categorical_accuracy: 0.9982 - val_loss: 2.0167 - val_sparse_categorical_accuracy: 0.5631
# Epoch 38/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0104 - sparse_categorical_accuracy: 0.9963 - val_loss: 0.9919 - val_sparse_categorical_accuracy: 0.6636
# Epoch 39/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0102 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.1903 - val_sparse_categorical_accuracy: 0.9159
# Epoch 40/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.3714 - val_sparse_categorical_accuracy: 0.8318
# Epoch 41/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.0458 - val_sparse_categorical_accuracy: 0.9836
# Epoch 42/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 1.0000
# Epoch 43/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0203 - sparse_categorical_accuracy: 0.9897 - val_loss: 0.0126 - val_sparse_categorical_accuracy: 0.9977
# Epoch 44/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0091 - sparse_categorical_accuracy: 0.9968 - val_loss: 0.0817 - val_sparse_categorical_accuracy: 0.9673
# Epoch 45/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0162 - sparse_categorical_accuracy: 0.9897 - val_loss: 0.0180 - val_sparse_categorical_accuracy: 0.9953
# Epoch 46/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0142 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.2374 - val_sparse_categorical_accuracy: 0.8879
# Epoch 47/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0137 - sparse_categorical_accuracy: 0.9956 - val_loss: 0.3955 - val_sparse_categorical_accuracy: 0.8458
# Epoch 48/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0229 - sparse_categorical_accuracy: 0.9938 - val_loss: 0.7809 - val_sparse_categorical_accuracy: 0.7804
# Epoch 49/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0338 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.1458 - val_sparse_categorical_accuracy: 0.9299
# Epoch 50/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0133 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.1873 - val_sparse_categorical_accuracy: 0.9089
# Epoch 51/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.3891 - val_sparse_categorical_accuracy: 0.8551
# Epoch 52/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0082 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.1369 - val_sparse_categorical_accuracy: 0.9369
# Epoch 53/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0176 - sparse_categorical_accuracy: 0.9932 - val_loss: 0.0763 - val_sparse_categorical_accuracy: 0.9696
# Epoch 54/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0203 - sparse_categorical_accuracy: 0.9948 - val_loss: 0.0178 - val_sparse_categorical_accuracy: 0.9930
# Epoch 55/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0203 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0016 - val_sparse_categorical_accuracy: 1.0000
# Epoch 56/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0213 - sparse_categorical_accuracy: 0.9940 - val_loss: 0.0015 - val_sparse_categorical_accuracy: 1.0000
# Epoch 57/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0135 - sparse_categorical_accuracy: 0.9953 - val_loss: 0.2016 - val_sparse_categorical_accuracy: 0.9276
# Epoch 58/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0062 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0035 - val_sparse_categorical_accuracy: 1.0000
# Epoch 59/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0374 - sparse_categorical_accuracy: 0.9881 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 1.0000
# Epoch 60/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0132 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.0105 - val_sparse_categorical_accuracy: 0.9977
# Epoch 61/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0112 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.0346 - val_sparse_categorical_accuracy: 0.9907
# Epoch 62/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0426 - val_sparse_categorical_accuracy: 0.9860
# Epoch 63/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0126 - sparse_categorical_accuracy: 0.9940 - val_loss: 0.0035 - val_sparse_categorical_accuracy: 1.0000
# Epoch 64/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0163 - sparse_categorical_accuracy: 0.9917 - val_loss: 0.0015 - val_sparse_categorical_accuracy: 1.0000
# Epoch 65/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0111 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.0092 - val_sparse_categorical_accuracy: 0.9953
# Epoch 66/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0063 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0115 - val_sparse_categorical_accuracy: 0.9953
# Epoch 67/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0187 - sparse_categorical_accuracy: 0.9926 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 1.0000
# Epoch 68/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0142 - sparse_categorical_accuracy: 0.9956 - val_loss: 0.0265 - val_sparse_categorical_accuracy: 0.9860
# Epoch 69/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.1074 - val_sparse_categorical_accuracy: 0.9369
# Epoch 70/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0063 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.0982 - val_sparse_categorical_accuracy: 0.9463
# Epoch 71/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0876 - val_sparse_categorical_accuracy: 0.9603
# Epoch 72/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0179 - sparse_categorical_accuracy: 0.9923 - val_loss: 0.1617 - val_sparse_categorical_accuracy: 0.9276
# Epoch 73/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0400 - val_sparse_categorical_accuracy: 0.9860
# Epoch 74/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0060 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0908 - val_sparse_categorical_accuracy: 0.9603
# Epoch 75/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0095 - sparse_categorical_accuracy: 0.9956 - val_loss: 0.0236 - val_sparse_categorical_accuracy: 0.9883
# Epoch 76/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0091 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.0621 - val_sparse_categorical_accuracy: 0.9743
# Epoch 77/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0166 - sparse_categorical_accuracy: 0.9935 - val_loss: 0.0388 - val_sparse_categorical_accuracy: 0.9860
# Epoch 78/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.1305 - val_sparse_categorical_accuracy: 0.9416
# Epoch 79/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.1858 - val_sparse_categorical_accuracy: 0.9252
# Epoch 80/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0580 - val_sparse_categorical_accuracy: 0.9696
# Epoch 81/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0127 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0084 - val_sparse_categorical_accuracy: 0.9953
# Epoch 82/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 1.0000
# Epoch 83/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0063 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.0013 - val_sparse_categorical_accuracy: 1.0000
# Epoch 84/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0103 - sparse_categorical_accuracy: 0.9948 - val_loss: 0.0026 - val_sparse_categorical_accuracy: 1.0000
# Epoch 85/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0209 - val_sparse_categorical_accuracy: 0.9953
# Epoch 86/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0195 - sparse_categorical_accuracy: 0.9941 - val_loss: 0.0538 - val_sparse_categorical_accuracy: 0.9836
# Epoch 87/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0118 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.4284 - val_sparse_categorical_accuracy: 0.8458
# Epoch 88/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0468 - val_sparse_categorical_accuracy: 0.9836
# Epoch 89/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0185 - val_sparse_categorical_accuracy: 0.9883
# Epoch 90/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0112 - sparse_categorical_accuracy: 0.9974 - val_loss: 0.0014 - val_sparse_categorical_accuracy: 1.0000
# Epoch 91/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0215 - sparse_categorical_accuracy: 0.9909 - val_loss: 0.0167 - val_sparse_categorical_accuracy: 0.9953
# Epoch 92/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0106 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0210 - val_sparse_categorical_accuracy: 0.9883
# Epoch 93/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0303 - val_sparse_categorical_accuracy: 0.9860
# Epoch 94/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0082 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.1873 - val_sparse_categorical_accuracy: 0.9182
# Epoch 95/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.0432 - val_sparse_categorical_accuracy: 0.9836
# Epoch 96/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0341 - val_sparse_categorical_accuracy: 0.9860
# Epoch 97/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0130 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0574 - val_sparse_categorical_accuracy: 0.9813
# Epoch 98/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9961 - val_loss: 0.0133 - val_sparse_categorical_accuracy: 0.9953
# Epoch 99/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0055 - sparse_categorical_accuracy: 0.9968 - val_loss: 0.0259 - val_sparse_categorical_accuracy: 0.9860
# Epoch 100/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0066 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.0103 - val_sparse_categorical_accuracy: 0.9953
# Epoch 101/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0059 - sparse_categorical_accuracy: 0.9982 - val_loss: 9.5883e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 102/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0120 - sparse_categorical_accuracy: 0.9936 - val_loss: 7.6361e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 103/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0187 - sparse_categorical_accuracy: 0.9919 - val_loss: 5.8133e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 104/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.0019 - val_sparse_categorical_accuracy: 1.0000
# Epoch 105/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0128 - sparse_categorical_accuracy: 0.9949 - val_loss: 0.5974 - val_sparse_categorical_accuracy: 0.8201
# Epoch 106/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0133 - sparse_categorical_accuracy: 0.9952 - val_loss: 0.0045 - val_sparse_categorical_accuracy: 1.0000
# Epoch 107/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0098 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0121 - val_sparse_categorical_accuracy: 0.9907
# Epoch 108/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0100 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.2686 - val_sparse_categorical_accuracy: 0.9439
# Epoch 109/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0092 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.0637 - val_sparse_categorical_accuracy: 0.9790
# Epoch 110/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0106 - sparse_categorical_accuracy: 0.9963 - val_loss: 0.2880 - val_sparse_categorical_accuracy: 0.9393
# Epoch 111/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.2442 - val_sparse_categorical_accuracy: 0.9439
# Epoch 112/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0141 - sparse_categorical_accuracy: 0.9941 - val_loss: 0.5825 - val_sparse_categorical_accuracy: 0.8949
# Epoch 113/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0095 - sparse_categorical_accuracy: 0.9974 - val_loss: 0.2033 - val_sparse_categorical_accuracy: 0.9486
# Epoch 114/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.0247 - val_sparse_categorical_accuracy: 0.9883
# Epoch 115/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0075 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.0085 - val_sparse_categorical_accuracy: 1.0000
# Epoch 116/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0073 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.0270 - val_sparse_categorical_accuracy: 0.9860
# Epoch 117/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0159 - sparse_categorical_accuracy: 0.9920 - val_loss: 0.0798 - val_sparse_categorical_accuracy: 0.9650
# Epoch 118/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0107 - sparse_categorical_accuracy: 0.9951 - val_loss: 1.5196 - val_sparse_categorical_accuracy: 0.7500
# Epoch 119/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.3196 - val_sparse_categorical_accuracy: 0.9276
# Epoch 120/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.0126 - val_sparse_categorical_accuracy: 0.9930
# Epoch 121/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0181 - sparse_categorical_accuracy: 0.9941 - val_loss: 9.1066e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 122/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0088 - sparse_categorical_accuracy: 0.9952 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 1.0000
# Epoch 123/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - sparse_categorical_accuracy: 1.0000 - val_loss: 6.3308e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 124/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0226 - sparse_categorical_accuracy: 0.9909 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 125/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0084 - sparse_categorical_accuracy: 0.9963 - val_loss: 0.0306 - val_sparse_categorical_accuracy: 0.9790
# Epoch 126/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 1.0000
# Epoch 127/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 1.0000
# Epoch 128/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - sparse_categorical_accuracy: 1.0000 - val_loss: 6.9013e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 129/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - sparse_categorical_accuracy: 0.9984 - val_loss: 7.9233e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 130/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0025 - val_sparse_categorical_accuracy: 1.0000
# Epoch 131/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099 - sparse_categorical_accuracy: 0.9976 - val_loss: 6.3167e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 132/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9994 - val_loss: 4.3485e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 133/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0491 - sparse_categorical_accuracy: 0.9848 - val_loss: 0.1662 - val_sparse_categorical_accuracy: 0.9509
# Epoch 134/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.1300 - val_sparse_categorical_accuracy: 0.9556
# Epoch 135/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 1.0000
# Epoch 136/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9994 - val_loss: 5.2428e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 137/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0196 - sparse_categorical_accuracy: 0.9926 - val_loss: 0.1227 - val_sparse_categorical_accuracy: 0.9486
# Epoch 138/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0027 - val_sparse_categorical_accuracy: 1.0000
# Epoch 139/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0187 - sparse_categorical_accuracy: 0.9895 - val_loss: 0.0023 - val_sparse_categorical_accuracy: 1.0000
# Epoch 140/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 141/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0089 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.0302 - val_sparse_categorical_accuracy: 0.9766
# Epoch 142/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0158 - sparse_categorical_accuracy: 0.9935 - val_loss: 0.1612 - val_sparse_categorical_accuracy: 0.9509
# Epoch 143/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0083 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.0070 - val_sparse_categorical_accuracy: 1.0000
# Epoch 144/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0013 - val_sparse_categorical_accuracy: 1.0000
# Epoch 145/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9989 - val_loss: 5.6668e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 146/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - sparse_categorical_accuracy: 0.9997 - val_loss: 7.3242e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 147/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0120 - sparse_categorical_accuracy: 0.9922 - val_loss: 7.4210e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 148/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.0026 - val_sparse_categorical_accuracy: 1.0000
# Epoch 149/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9996 - val_loss: 9.7977e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 150/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0013 - val_sparse_categorical_accuracy: 1.0000
# Epoch 151/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.2890e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 152/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0057 - val_sparse_categorical_accuracy: 1.0000
# Epoch 153/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0130 - sparse_categorical_accuracy: 0.9943 - val_loss: 3.5957e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 154/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0053 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.0013 - val_sparse_categorical_accuracy: 1.0000
# Epoch 155/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0139 - val_sparse_categorical_accuracy: 0.9930
# Epoch 156/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0097 - sparse_categorical_accuracy: 0.9961 - val_loss: 2.9041e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 157/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0078 - sparse_categorical_accuracy: 0.9973 - val_loss: 4.6588e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 158/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - sparse_categorical_accuracy: 0.9997 - val_loss: 4.4053e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 159/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - sparse_categorical_accuracy: 0.9988 - val_loss: 4.5824e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 160/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0056 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0017 - val_sparse_categorical_accuracy: 1.0000
# Epoch 161/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0163 - sparse_categorical_accuracy: 0.9937 - val_loss: 4.7702e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 162/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0062 - sparse_categorical_accuracy: 0.9966 - val_loss: 2.7783e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 163/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0156 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 1.0000
# Epoch 164/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0074 - sparse_categorical_accuracy: 0.9983 - val_loss: 2.3832e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 165/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9988 - val_loss: 7.3211e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 166/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0130 - sparse_categorical_accuracy: 0.9952 - val_loss: 3.6195e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 167/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.0014 - val_sparse_categorical_accuracy: 1.0000
# Epoch 168/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0093 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.0530 - val_sparse_categorical_accuracy: 0.9720
# Epoch 169/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0055 - sparse_categorical_accuracy: 0.9981 - val_loss: 5.2788e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 170/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0078 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.0043 - val_sparse_categorical_accuracy: 1.0000
# Epoch 171/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0149 - sparse_categorical_accuracy: 0.9939 - val_loss: 0.0023 - val_sparse_categorical_accuracy: 1.0000
# Epoch 172/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9990 - val_loss: 7.7670e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 173/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0069 - sparse_categorical_accuracy: 0.9983 - val_loss: 6.8566e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 174/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9987 - val_loss: 2.3444e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 175/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0025 - val_sparse_categorical_accuracy: 1.0000
# Epoch 176/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0072 - sparse_categorical_accuracy: 0.9996 - val_loss: 0.0042 - val_sparse_categorical_accuracy: 1.0000
# Epoch 177/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0013 - val_sparse_categorical_accuracy: 1.0000
# Epoch 178/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0187 - sparse_categorical_accuracy: 0.9909 - val_loss: 2.0777e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 179/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - sparse_categorical_accuracy: 0.9996 - val_loss: 1.5790e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 180/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0066 - sparse_categorical_accuracy: 0.9959 - val_loss: 0.0016 - val_sparse_categorical_accuracy: 1.0000
# Epoch 181/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0025 - val_sparse_categorical_accuracy: 1.0000
# Epoch 182/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0072 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 1.0000
# Epoch 183/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0054 - sparse_categorical_accuracy: 0.9995 - val_loss: 6.0377e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 184/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0020 - val_sparse_categorical_accuracy: 1.0000
# Epoch 185/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0093 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0576 - val_sparse_categorical_accuracy: 0.9720
# Epoch 186/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0094 - sparse_categorical_accuracy: 0.9957 - val_loss: 0.0468 - val_sparse_categorical_accuracy: 0.9720
# Epoch 187/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0071 - sparse_categorical_accuracy: 0.9971 - val_loss: 0.0113 - val_sparse_categorical_accuracy: 0.9930
# Epoch 188/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0126 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.0249 - val_sparse_categorical_accuracy: 0.9860
# Epoch 189/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0080 - sparse_categorical_accuracy: 0.9983 - val_loss: 8.6561e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 190/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0062 - sparse_categorical_accuracy: 0.9963 - val_loss: 0.0013 - val_sparse_categorical_accuracy: 1.0000
# Epoch 191/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0165 - sparse_categorical_accuracy: 0.9976 - val_loss: 3.9259e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 192/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - sparse_categorical_accuracy: 0.9996 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 193/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - sparse_categorical_accuracy: 0.9990 - val_loss: 7.4874e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 194/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 1.0000
# Epoch 195/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0140 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0013 - val_sparse_categorical_accuracy: 1.0000
# Epoch 196/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0173 - sparse_categorical_accuracy: 0.9934 - val_loss: 0.0084 - val_sparse_categorical_accuracy: 0.9977
# Epoch 197/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0078 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0049 - val_sparse_categorical_accuracy: 1.0000
# Epoch 198/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 1.0000
# Epoch 199/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9990 - val_loss: 3.7473e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 200/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 201/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0460 - val_sparse_categorical_accuracy: 0.9766
# Epoch 202/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0087 - val_sparse_categorical_accuracy: 0.9977
# Epoch 203/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0040 - val_sparse_categorical_accuracy: 1.0000
# Epoch 204/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0094 - val_sparse_categorical_accuracy: 0.9977
# Epoch 205/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.4435 - val_sparse_categorical_accuracy: 0.9042
# Epoch 206/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0059 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.4872 - val_sparse_categorical_accuracy: 0.9182
# Epoch 207/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0175 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.1885 - val_sparse_categorical_accuracy: 0.9509
# Epoch 208/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0128 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0341 - val_sparse_categorical_accuracy: 0.9790
# Epoch 209/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0056 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.0496 - val_sparse_categorical_accuracy: 0.9743
# Epoch 210/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0279 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.3205 - val_sparse_categorical_accuracy: 0.9252
# Epoch 211/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0661 - val_sparse_categorical_accuracy: 0.9720
# Epoch 212/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0160 - val_sparse_categorical_accuracy: 0.9907
# Epoch 213/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0077 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0479 - val_sparse_categorical_accuracy: 0.9720
# Epoch 214/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0037 - val_sparse_categorical_accuracy: 1.0000
# Epoch 215/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0103 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.0167 - val_sparse_categorical_accuracy: 0.9907
# Epoch 216/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 217/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0207 - val_sparse_categorical_accuracy: 0.9907
# Epoch 218/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0061 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.0519 - val_sparse_categorical_accuracy: 0.9720
# Epoch 219/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0156 - val_sparse_categorical_accuracy: 0.9907
# Epoch 220/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0315 - sparse_categorical_accuracy: 0.9866 - val_loss: 2.6011 - val_sparse_categorical_accuracy: 0.5210
# Epoch 221/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0148 - sparse_categorical_accuracy: 0.9960 - val_loss: 0.0120 - val_sparse_categorical_accuracy: 0.9930
# Epoch 222/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9997 - val_loss: 3.6506e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 223/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0071 - sparse_categorical_accuracy: 0.9979 - val_loss: 3.8553e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 224/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0064 - sparse_categorical_accuracy: 0.9961 - val_loss: 2.4123e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 225/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - sparse_categorical_accuracy: 0.9995 - val_loss: 2.3616e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 226/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9992 - val_loss: 3.6650e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 227/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9983 - val_loss: 5.5353e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 228/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0013 - val_sparse_categorical_accuracy: 1.0000
# Epoch 229/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0107 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0014 - val_sparse_categorical_accuracy: 1.0000
# Epoch 230/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0113 - sparse_categorical_accuracy: 0.9968 - val_loss: 4.1911e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 231/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.5609e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 232/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0073 - sparse_categorical_accuracy: 0.9971 - val_loss: 0.0017 - val_sparse_categorical_accuracy: 1.0000
# Epoch 233/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.7933e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 234/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0117 - sparse_categorical_accuracy: 0.9949 - val_loss: 0.0788 - val_sparse_categorical_accuracy: 0.9696
# Epoch 235/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0059 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0247 - val_sparse_categorical_accuracy: 0.9860
# Epoch 236/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0062 - sparse_categorical_accuracy: 0.9959 - val_loss: 0.0034 - val_sparse_categorical_accuracy: 1.0000
# Epoch 237/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 238/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0245 - val_sparse_categorical_accuracy: 0.9883
# Epoch 239/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 1.0000
# Epoch 240/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.4152 - val_sparse_categorical_accuracy: 0.9019
# Epoch 241/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.0615 - val_sparse_categorical_accuracy: 0.9720
# Epoch 242/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0214 - sparse_categorical_accuracy: 0.9934 - val_loss: 0.2737 - val_sparse_categorical_accuracy: 0.8995
# Epoch 243/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0061 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0013 - val_sparse_categorical_accuracy: 1.0000
# Epoch 244/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0020 - val_sparse_categorical_accuracy: 1.0000
# Epoch 245/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9990 - val_loss: 8.4568e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 246/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9988 - val_loss: 4.5065e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 247/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - sparse_categorical_accuracy: 0.9999 - val_loss: 2.3738e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 248/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.4020e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 249/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0023 - val_sparse_categorical_accuracy: 1.0000
# Epoch 250/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - sparse_categorical_accuracy: 0.9970 - val_loss: 1.8844e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 251/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9977 - val_loss: 3.1150e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 252/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0039 - val_sparse_categorical_accuracy: 1.0000
# Epoch 253/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - sparse_categorical_accuracy: 0.9998 - val_loss: 2.9972e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 254/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0094 - sparse_categorical_accuracy: 0.9963 - val_loss: 0.0023 - val_sparse_categorical_accuracy: 1.0000
# Epoch 255/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 256/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0260 - sparse_categorical_accuracy: 0.9929 - val_loss: 0.0151 - val_sparse_categorical_accuracy: 0.9930
# Epoch 257/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0091 - sparse_categorical_accuracy: 0.9975 - val_loss: 4.1794e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 258/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0053 - sparse_categorical_accuracy: 0.9980 - val_loss: 9.6431e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 259/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9999 - val_loss: 2.1266e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 260/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9993 - val_loss: 2.5883e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 261/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - sparse_categorical_accuracy: 0.9960 - val_loss: 2.2997e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 262/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0185 - sparse_categorical_accuracy: 0.9928 - val_loss: 0.1211 - val_sparse_categorical_accuracy: 0.9556
# Epoch 263/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 264/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0061 - sparse_categorical_accuracy: 0.9979 - val_loss: 3.1323e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 265/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0075 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0039 - val_sparse_categorical_accuracy: 1.0000
# Epoch 266/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - sparse_categorical_accuracy: 0.9998 - val_loss: 5.6594e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 267/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9995 - val_loss: 3.2230e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 268/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - sparse_categorical_accuracy: 0.9999 - val_loss: 1.6170e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 269/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0088 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.0799 - val_sparse_categorical_accuracy: 0.9696
# Epoch 270/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.0017 - val_sparse_categorical_accuracy: 1.0000
# Epoch 271/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 272/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0174 - sparse_categorical_accuracy: 0.9930 - val_loss: 4.8378e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 273/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - sparse_categorical_accuracy: 0.9997 - val_loss: 1.8734e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 274/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023 - sparse_categorical_accuracy: 0.9995 - val_loss: 1.5381e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 275/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - sparse_categorical_accuracy: 0.9996 - val_loss: 6.6228e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 276/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9996 - val_loss: 2.1955e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 277/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2428 - val_sparse_categorical_accuracy: 0.9136
# Epoch 278/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0211 - sparse_categorical_accuracy: 0.9921 - val_loss: 0.3293 - val_sparse_categorical_accuracy: 0.9065
# Epoch 279/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0860 - val_sparse_categorical_accuracy: 0.9650
# Epoch 280/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0103 - val_sparse_categorical_accuracy: 0.9953
# Epoch 281/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0088 - sparse_categorical_accuracy: 0.9960 - val_loss: 0.0034 - val_sparse_categorical_accuracy: 1.0000
# Epoch 282/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0055 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.0171 - val_sparse_categorical_accuracy: 0.9883
# Epoch 283/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.8358e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 284/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0102 - sparse_categorical_accuracy: 0.9959 - val_loss: 0.0096 - val_sparse_categorical_accuracy: 0.9977
# Epoch 285/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.0343 - val_sparse_categorical_accuracy: 0.9813
# Epoch 286/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0054 - val_sparse_categorical_accuracy: 1.0000
# Epoch 287/500
# ...
# Epoch 407/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0044 - val_sparse_categorical_accuracy: 1.0000
# Epoch 408/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2559e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 409/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.3412e-04 - sparse_categorical_accuracy: 0.9999 - val_loss: 5.8532e-05 - val_sparse_categorical_accuracy: 1.0000
# Epoch 410/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0014 - val_sparse_categorical_accuracy: 1.0000
# Epoch 411/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - sparse_categorical_accuracy: 1.0000 - val_loss: 7.9451e-05 - val_sparse_categorical_accuracy: 1.0000
# Epoch 412/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0056 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0420 - val_sparse_categorical_accuracy: 0.9860
# Epoch 413/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0310 - sparse_categorical_accuracy: 0.9898 - val_loss: 0.1453 - val_sparse_categorical_accuracy: 0.9556
# Epoch 414/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0084 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0067 - val_sparse_categorical_accuracy: 0.9977
# Epoch 415/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0141 - val_sparse_categorical_accuracy: 0.9907
# Epoch 416/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9996 - val_loss: 0.0228 - val_sparse_categorical_accuracy: 0.9907
# Epoch 417/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.0044 - val_sparse_categorical_accuracy: 1.0000
# Epoch 418/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0087 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0016 - val_sparse_categorical_accuracy: 1.0000
# Epoch 419/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0014 - val_sparse_categorical_accuracy: 1.0000
# Epoch 420/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0067 - val_sparse_categorical_accuracy: 0.9977
# Epoch 421/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0274 - val_sparse_categorical_accuracy: 0.9836
# Epoch 422/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0249 - val_sparse_categorical_accuracy: 0.9883
# Epoch 423/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0122 - sparse_categorical_accuracy: 0.9939 - val_loss: 0.0854 - val_sparse_categorical_accuracy: 0.9673
# Epoch 424/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0019 - val_sparse_categorical_accuracy: 1.0000
# Epoch 425/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 1.0000
# Epoch 426/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - sparse_categorical_accuracy: 0.9997 - val_loss: 1.6620e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 427/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.1630e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 428/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0060 - sparse_categorical_accuracy: 0.9957 - val_loss: 0.0151 - val_sparse_categorical_accuracy: 0.9930
# Epoch 429/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9985 - val_loss: 9.3773e-05 - val_sparse_categorical_accuracy: 1.0000
# Epoch 430/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9982 - val_loss: 5.9484e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 431/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.9196e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 432/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0083 - sparse_categorical_accuracy: 0.9973 - val_loss: 2.5168e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 433/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9994 - val_loss: 2.2794e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 434/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - sparse_categorical_accuracy: 0.9997 - val_loss: 9.7875e-05 - val_sparse_categorical_accuracy: 1.0000
# Epoch 435/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3404e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 9.6628e-05 - val_sparse_categorical_accuracy: 1.0000
# Epoch 436/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3301e-04 - sparse_categorical_accuracy: 0.9999 - val_loss: 5.6330e-05 - val_sparse_categorical_accuracy: 1.0000
# Epoch 437/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9984 - val_loss: 8.3277e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 438/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.7451 - val_sparse_categorical_accuracy: 0.7687
# Epoch 439/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0388 - sparse_categorical_accuracy: 0.9876 - val_loss: 8.5712e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 440/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - sparse_categorical_accuracy: 1.0000 - val_loss: 5.8155e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 441/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.0023 - val_sparse_categorical_accuracy: 1.0000
# Epoch 442/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9998 - val_loss: 5.2057e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 443/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9984 - val_loss: 1.8212e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 444/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8502e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 8.3266e-05 - val_sparse_categorical_accuracy: 1.0000
# Epoch 445/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0302 - sparse_categorical_accuracy: 0.9902 - val_loss: 0.0862 - val_sparse_categorical_accuracy: 0.9673
# Epoch 446/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0147 - val_sparse_categorical_accuracy: 0.9907
# Epoch 447/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0045 - val_sparse_categorical_accuracy: 1.0000
# Epoch 448/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5359e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2522e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 449/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.6789e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 450/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9974 - val_loss: 1.4596e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 451/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - sparse_categorical_accuracy: 0.9996 - val_loss: 2.4951e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 452/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2495e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 453/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0091 - sparse_categorical_accuracy: 0.9978 - val_loss: 1.2378e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 454/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0047 - sparse_categorical_accuracy: 0.9955 - val_loss: 1.4180e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 455/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0917e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 456/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - sparse_categorical_accuracy: 0.9992 - val_loss: 6.7575e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 457/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1260e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.8376e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 458/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2823e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.0388e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 459/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - sparse_categorical_accuracy: 0.9999 - val_loss: 3.5644e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 460/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012 - sparse_categorical_accuracy: 1.0000 - val_loss: 8.1427e-05 - val_sparse_categorical_accuracy: 1.0000
# Epoch 461/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - sparse_categorical_accuracy: 0.9996 - val_loss: 1.7683e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 462/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0117 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0066 - val_sparse_categorical_accuracy: 1.0000
# Epoch 463/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0015 - val_sparse_categorical_accuracy: 1.0000
# Epoch 464/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.1768e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 465/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0016 - val_sparse_categorical_accuracy: 1.0000
# Epoch 466/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0056 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.1348 - val_sparse_categorical_accuracy: 0.9509
# Epoch 467/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0171 - sparse_categorical_accuracy: 0.9947 - val_loss: 0.0543 - val_sparse_categorical_accuracy: 0.9720
# Epoch 468/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0053 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 1.0000
# Epoch 469/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0059 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.0817 - val_sparse_categorical_accuracy: 0.9650
# Epoch 470/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0424 - val_sparse_categorical_accuracy: 0.9766
# Epoch 471/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0221 - val_sparse_categorical_accuracy: 0.9930
# Epoch 472/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 473/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0046 - sparse_categorical_accuracy: 0.9987 - val_loss: 4.4125e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 474/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9996 - val_loss: 0.0063 - val_sparse_categorical_accuracy: 0.9977
# Epoch 475/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0093 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0273 - val_sparse_categorical_accuracy: 0.9813
# Epoch 476/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0247 - val_sparse_categorical_accuracy: 0.9860
# Epoch 477/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - sparse_categorical_accuracy: 1.0000 - val_loss: 9.1804e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 478/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9082e-04 - sparse_categorical_accuracy: 0.9999 - val_loss: 1.7047e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 479/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0061 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2251 - val_sparse_categorical_accuracy: 0.9463
# Epoch 480/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0059 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0226 - val_sparse_categorical_accuracy: 0.9860
# Epoch 481/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0639 - val_sparse_categorical_accuracy: 0.9720
# Epoch 482/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5173e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0026 - val_sparse_categorical_accuracy: 1.0000
# Epoch 483/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0346 - val_sparse_categorical_accuracy: 0.9766
# Epoch 484/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.0152 - val_sparse_categorical_accuracy: 0.9930
# Epoch 485/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0071 - sparse_categorical_accuracy: 0.9985 - val_loss: 2.4520e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 486/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2677e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.3924e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 487/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.0523 - val_sparse_categorical_accuracy: 0.9720
# Epoch 488/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - sparse_categorical_accuracy: 0.9986 - val_loss: 8.0837e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 489/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0346 - val_sparse_categorical_accuracy: 0.9836
# Epoch 490/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.1387 - val_sparse_categorical_accuracy: 0.9579
# Epoch 491/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 1.0000
# Epoch 492/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4642e-04 - sparse_categorical_accuracy: 0.9999 - val_loss: 1.0871e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 493/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - sparse_categorical_accuracy: 0.9999 - val_loss: 8.5477e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 494/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 495/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.0419 - val_sparse_categorical_accuracy: 0.9790
# Epoch 496/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - sparse_categorical_accuracy: 0.9996 - val_loss: 0.2245 - val_sparse_categorical_accuracy: 0.9416
# Epoch 497/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.2472 - val_sparse_categorical_accuracy: 0.9369
# Epoch 498/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.9550e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0489 - val_sparse_categorical_accuracy: 0.9743
# Epoch 499/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0054 - val_sparse_categorical_accuracy: 1.0000
# Epoch 500/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8226e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.8377e-04 - val_sparse_categorical_accuracy: 1.0000

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df[['loss', 'val_loss']].plot()
# Out:
# <Axes: >

# %%
loss_df[['sparse_categorical_accuracy', 'val_sparse_categorical_accuracy']].plot()
# Out:
# <Axes: >

# %%
# compare the final model loss/accuracy/evaluation values
# the values should again match mostly
print("Test data evaluation:")
print(model.evaluate(x_test, y_test, verbose=0))
print("\nTrain data evaluation:")
print(model.evaluate(x_train, y_train, verbose=0))
# Out:
# Test data evaluation:
# [0.0001566036808071658, 1.0]
#
# Train data evaluation:
# [0.0001611962798051536, 1.0]

# %%
# get predictions and convert with argmax() to get categories 
# instead of raw probabilities
test_predictions = model.predict(x_test)
test_predictions = np.argmax(test_predictions, axis=1)
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# confusion matrix
import seaborn as sns
sns.heatmap(confusion_matrix(y_test, test_predictions), annot=True, fmt='g')
# Out:
# <Axes: >

# %%
# print the classification report based on true values and predictions
print(classification_report(y_test, test_predictions))

# get overall accuracy of the model and print it
acc = accuracy_score(y_test, test_predictions)
print("\nModel overall accuracy: {:.2f}%".format(acc * 100))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       456
#            1       1.00      1.00      1.00       461
#
#     accuracy                           1.00       917
#    macro avg       1.00      1.00      1.00       917
# weighted avg       1.00      1.00      1.00       917
#
#
# Model overall accuracy: 100.00%

# %% [markdown]
# <b>Test the model with some imaginary/synthetic signal examples from ChatGPT</b>

# %%
signal_index = 8
print(y_test[signal_index])
print(class_names[y_test[signal_index]])

plt.figure()
plt.plot(x_test[signal_index])
plt.show()
# Out:
# 1
# wind_speed

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create x values from 0 to 49
x = np.arange(50)

# Create y values that fluctuate around 0.2
np.random.seed(0)  # For reproducibility
y = 0.2 + np.random.normal(0, 0.05, size=x.shape)

# Introduce spikes
y[15:20] += 0.3  # First spike
y[35:40] += 0.3  # Second spike

# Optional: Clip y values to avoid extreme outliers
y = np.clip(y, 0, 1)

# Plot the result (optional)
plt.plot(x, y)
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Y values fluctuating around 0.2 with spikes')
plt.show()

# y now contains the desired values

# %%
points = y
test_signal = np.expand_dims(points, axis=1)
test_batch = np.array([test_signal])

test_predict = model.predict(test_batch)
print(test_predict)

index = np.argmax(test_predict)
print(class_names[index])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# [[3.2798997e-07 9.9999964e-01]]
# wind_speed

# %%
signal_index = 22
print(y_test[signal_index])
print(class_names[y_test[signal_index]])

plt.figure()
plt.plot(x_test[signal_index])
plt.show()
# Out:
# 0
# meantemp

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create x values from 0 to 49
x = np.arange(50)

# Create y values that fluctuate around 0.5
np.random.seed(0)  # For reproducibility
y = 0.5 + np.random.normal(0, 0.05, size=x.shape)

# Introduce a valley around the middle (indices 20 to 30)
y[14:36] -= 0.2 + np.random.normal(0, 0.02, size=22)  # Valley around 0.2

# Optional: Clip y values to avoid extreme outliers
y = np.clip(y, 0, 1)

# Plot the result (optional)
plt.plot(x, y)
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Y values fluctuating around 0.5 with a valley')
plt.show()

# y now contains the desired values

# %%
points = y
test_signal = np.expand_dims(points, axis=1)
test_batch = np.array([test_signal])

test_predict = model.predict(test_batch)
print(test_predict)

index = np.argmax(test_predict)
print(class_names[index])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# [[9.9994123e-01 5.8762434e-05]]
# meantemp
