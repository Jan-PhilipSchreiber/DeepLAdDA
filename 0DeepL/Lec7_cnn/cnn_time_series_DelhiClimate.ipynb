# %% [markdown]
# <b>CNN for time series classification, example 2, Delhi Climate data</b>

# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# if your Jupyter kernel crashes during this code, use this setting
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# %%
df1 = pd.read_csv("DailyDelhiClimateTrain.csv")
df2 = pd.read_csv("DailyDelhiClimateTest.csv")

# combine datasets and reset the index (so that we 
# have a sequence number alongside the timestamp))
df = pd.concat([df1, df2])
df = df.reset_index()

# %%
df.head()
# Out:
#    index        date   meantemp   humidity  wind_speed  meanpressure
# 0      0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1      1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2      2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3      3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4      4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
df.describe()
# Out:
#              index     meantemp     humidity   wind_speed  meanpressure
# count  1576.000000  1576.000000  1576.000000  1576.000000   1576.000000
# mean    681.746193    25.221918    60.445229     6.899262   1010.593178
# std     442.630431     7.345014    16.979994     4.510725    175.242704
# min       0.000000     6.000000    13.428571     0.000000     -3.041667
# 25%     279.750000    18.500000    49.750000     3.700000   1001.875000
# 50%     673.500000    27.166667    62.440476     6.363571   1009.055556
# 75%    1067.250000    31.142857    72.125000     9.262500   1015.200000
# max    1461.000000    38.714286   100.000000    42.220000   7679.333333

# %%
# this dataformat is not suitable yet for CNN time series classification
# because each point is separate in the dataset

# we have to process the data into smaller chunks -> for example
# chunks of 50 points at a time

# we are going to select meantemp and wind_speed as our target outputs
df = df.drop(['humidity', 'meanpressure'], axis=1)

# %%
df.head()
# Out:
#    index        date   meantemp  wind_speed
# 0      0  2013-01-01  10.000000    0.000000
# 1      1  2013-01-02   7.400000    2.980000
# 2      2  2013-01-03   7.166667    4.633333
# 3      3  2013-01-04   8.666667    1.233333
# 4      4  2013-01-05   6.000000    3.700000

# %% [markdown]
# <b>Scale the values (important in CNN)</b>

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# cale only relevant variables
num_cols = ['meantemp', 'wind_speed']
df[num_cols] = scaler.fit_transform(df[num_cols])

# %%
df.head()
# Out:
#    index        date  meantemp  wind_speed
# 0      0  2013-01-01  0.122271    0.000000
# 1      1  2013-01-02  0.042795    0.070583
# 2      2  2013-01-03  0.035662    0.109743
# 3      3  2013-01-04  0.081514    0.029212
# 4      4  2013-01-05  0.000000    0.087636

# %%
# instead of the date-column and old index,
# let's use a sequence number
# starting from 1 until the final row
df['sequence'] = df.index + 1
df = df.drop(['date', 'index'], axis=1)

# %%
df.tail()
# Out:
#       meantemp  wind_speed  sequence
# 1571  0.871179    0.131750      1572
# 1572  0.863537    0.164910      1573
# 1573  0.822271    0.210564      1574
# 1574  0.821507    0.235966      1575
# 1575  0.794760    0.287947      1576

# %% [markdown]
# <b>Split the DataFrame into timesteps</b>

# %%
from numpy.lib.stride_tricks import sliding_window_view

timestep_size = 50

# separate the output variables
meantemp = df['meantemp'].values
wind_speed = df['wind_speed'].values

# generate timestep windows for each signal
meantemp_windows = sliding_window_view(meantemp, window_shape=timestep_size)
wind_speed_windows = sliding_window_view(wind_speed, window_shape=timestep_size)

# combine into X and y
# use vstack to combine temperatures and wind speeds back together
X = np.vstack((meantemp_windows, wind_speed_windows))

# generate zeroes and ones for the output categories
# 0 = meantemp
# 1 = wind_speed
y = np.array([0] * len(meantemp_windows) + [1] * len(wind_speed_windows))

print("X:", X.shape)
print("y:", y.shape)
# Out:
# X: (3054, 50)
# y: (3054,)

# %%
from sklearn.utils import shuffle

# shuffle the data
X, y = shuffle(X, y, random_state=42)

# %%
test_signal_index = 2

c_x_train = X[y == 0]
plt.plot(c_x_train[test_signal_index], label="Class 0: meantemp")

c_x_train = X[y == 1]
plt.plot(c_x_train[test_signal_index], label="Class 1: wind_speed")
plt.legend()

# %% [markdown]
# <b>Finally we can do the train/test split</b>

# %%
# define the cutoff point
train_size = 0.7
splitter = int(len(X) * train_size)

# split to train/test
x_train = X[0:splitter]
x_test = X[splitter:]
y_train = y[0:splitter]
y_test = y[splitter:]

# %%
print(len(x_train))
print(len(x_test))
print(len(y_train))
print(len(y_test))
# Out:
# 2137
# 917
# 2137
# 917

# %%
x_train
# Out:
# array([[0.73362445, 0.6768559 , 0.63755459, ..., 0.35534934, 0.33624454,
#         0.32478166],
#        [0.82532751, 0.79475983, 0.77565502, ..., 0.7680131 , 0.74672489,
#         0.77565502],
#        [0.7802804 , 0.83197266, 0.89469264, ..., 0.81195415, 0.77947598,
#         0.7489083 ],
#        ...,
#        [0.72925764, 0.7860262 , 0.80349345, ..., 0.77947598, 0.83296943,
#         0.8202329 ],
#        [0.50436681, 0.70815138, 0.54512373, ..., 0.81386463, 0.81768559,
#         0.82150655],
#        [0.28511369, 0.35084083, 0.57614874, ..., 0.14803411, 0.4275225 ,
#         0.13707958]])

# %%
# convert the data into the required CNN -format
# usuallu the easiest approach is to modify
# your own data to follow the data format used by another example 
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# %%
x_train
# Out:
# array([[[0.73362445],
#         [0.6768559 ],
#         [0.63755459],
#         ...,
#         [0.35534934],
#         [0.33624454],
#         [0.32478166]],
#
#        [[0.82532751],
#         [0.79475983],
#         [0.77565502],
#         ...,
#         [0.7680131 ],
#         [0.74672489],
#         [0.77565502]],
#
#        [[0.7802804 ],
#         [0.83197266],
#         [0.89469264],
#         ...,
#         [0.81195415],
#         [0.77947598],
#         [0.7489083 ]],
#
#        ...,
#
#        [[0.72925764],
#         [0.7860262 ],
#         [0.80349345],
#         ...,
#         [0.77947598],
#         [0.83296943],
#         [0.8202329 ]],
#
#        [[0.50436681],
#         [0.70815138],
#         [0.54512373],
#         ...,
#         [0.81386463],
#         [0.81768559],
#         [0.82150655]],
#
#        [[0.28511369],
#         [0.35084083],
#         [0.57614874],
#         ...,
#         [0.14803411],
#         [0.4275225 ],
#         [0.13707958]]])

# %%
class_names = np.array(["meantemp", "wind_speed"])
num_classes = len(class_names)
classes = [0, 1]

def make_model(input_shape):
    model = keras.Sequential(
        [
            # input layer
            keras.layers.Input(input_shape),

            # convolutional layer 1 (we usually have 1-3 convolutional layers
            # depending how much and how complex the data is) -> "model capacity / decision space"
            keras.layers.Conv1D(filters=64, kernel_size=3, padding="same"),
            keras.layers.BatchNormalization(),
            keras.layers.ReLU(),

            # pooling + flatten (adapter from convolutional to dense)
            # flattening is done only once after the final convolutional layer 
            # and before the Dense-network
            keras.layers.GlobalAveragePooling1D(),
            keras.layers.Flatten(),

            # neural network Dense-tail
            keras.layers.Dense(64, activation="relu"),

            # output layer
            keras.layers.Dense(num_classes, activation="softmax")
        ]
    )

    return model


model = make_model(input_shape=x_train.shape[1:])

# pip install pydot -> restart Kernel
# keras.utils.plot_model(model, show_shapes=True)

# %%
epochs = 500
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model2.keras", save_best_only=True, monitor="val_loss"
    ),

]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4518 - sparse_categorical_accuracy: 0.7783 - val_loss: 0.6286 - val_sparse_categorical_accuracy: 0.4790
# Epoch 2/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1905 - sparse_categorical_accuracy: 0.9132 - val_loss: 0.6569 - val_sparse_categorical_accuracy: 0.4790
# Epoch 3/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1669 - sparse_categorical_accuracy: 0.9280 - val_loss: 0.7130 - val_sparse_categorical_accuracy: 0.4790
# Epoch 4/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1521 - sparse_categorical_accuracy: 0.9341 - val_loss: 0.7501 - val_sparse_categorical_accuracy: 0.4790
# Epoch 5/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1402 - sparse_categorical_accuracy: 0.9438 - val_loss: 0.6933 - val_sparse_categorical_accuracy: 0.5164
# Epoch 6/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1402 - sparse_categorical_accuracy: 0.9436 - val_loss: 0.6168 - val_sparse_categorical_accuracy: 0.5421
# Epoch 7/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1028 - sparse_categorical_accuracy: 0.9647 - val_loss: 0.5479 - val_sparse_categorical_accuracy: 0.5981
# Epoch 8/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1203 - sparse_categorical_accuracy: 0.9480 - val_loss: 0.2413 - val_sparse_categorical_accuracy: 0.9346
# Epoch 9/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0918 - sparse_categorical_accuracy: 0.9656 - val_loss: 0.1872 - val_sparse_categorical_accuracy: 0.9860
# Epoch 10/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0855 - sparse_categorical_accuracy: 0.9765 - val_loss: 0.1250 - val_sparse_categorical_accuracy: 0.9813
# Epoch 11/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0764 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.1068 - val_sparse_categorical_accuracy: 0.9883
# Epoch 12/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0702 - sparse_categorical_accuracy: 0.9713 - val_loss: 0.0724 - val_sparse_categorical_accuracy: 0.9766
# Epoch 13/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0620 - sparse_categorical_accuracy: 0.9808 - val_loss: 0.0632 - val_sparse_categorical_accuracy: 0.9696
# Epoch 14/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0660 - sparse_categorical_accuracy: 0.9742 - val_loss: 0.0587 - val_sparse_categorical_accuracy: 0.9720
# Epoch 15/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0529 - sparse_categorical_accuracy: 0.9819 - val_loss: 0.0477 - val_sparse_categorical_accuracy: 0.9907
# Epoch 16/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0575 - sparse_categorical_accuracy: 0.9826 - val_loss: 0.0445 - val_sparse_categorical_accuracy: 0.9883
# Epoch 17/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0389 - sparse_categorical_accuracy: 0.9890 - val_loss: 0.0509 - val_sparse_categorical_accuracy: 0.9720
# Epoch 18/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0319 - sparse_categorical_accuracy: 0.9901 - val_loss: 0.0373 - val_sparse_categorical_accuracy: 0.9860
# Epoch 19/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0395 - sparse_categorical_accuracy: 0.9901 - val_loss: 0.0403 - val_sparse_categorical_accuracy: 0.9836
# Epoch 20/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0321 - sparse_categorical_accuracy: 0.9936 - val_loss: 0.0298 - val_sparse_categorical_accuracy: 0.9907
# Epoch 21/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0348 - sparse_categorical_accuracy: 0.9854 - val_loss: 0.0404 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0286 - sparse_categorical_accuracy: 0.9886 - val_loss: 0.0972 - val_sparse_categorical_accuracy: 0.9766
# Epoch 23/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0306 - sparse_categorical_accuracy: 0.9892 - val_loss: 0.0882 - val_sparse_categorical_accuracy: 0.9766
# Epoch 24/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0285 - sparse_categorical_accuracy: 0.9892 - val_loss: 0.1929 - val_sparse_categorical_accuracy: 0.9089
# Epoch 25/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0263 - sparse_categorical_accuracy: 0.9926 - val_loss: 0.2084 - val_sparse_categorical_accuracy: 0.8995
# Epoch 26/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0234 - sparse_categorical_accuracy: 0.9935 - val_loss: 0.0431 - val_sparse_categorical_accuracy: 0.9953
# Epoch 27/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0181 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.1064 - val_sparse_categorical_accuracy: 0.9579
# Epoch 28/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0128 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.1650 - val_sparse_categorical_accuracy: 0.9229
# Epoch 29/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0142 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0547 - val_sparse_categorical_accuracy: 0.9860
# Epoch 30/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0124 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.0299 - val_sparse_categorical_accuracy: 0.9953
# Epoch 31/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0263 - sparse_categorical_accuracy: 0.9913 - val_loss: 0.0332 - val_sparse_categorical_accuracy: 0.9953
# Epoch 32/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0122 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0127 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0155 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0516 - val_sparse_categorical_accuracy: 0.9953
# Epoch 34/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0096 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0914 - val_sparse_categorical_accuracy: 0.9673
# Epoch 35/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0259 - sparse_categorical_accuracy: 0.9927 - val_loss: 0.0034 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0166 - sparse_categorical_accuracy: 0.9961 - val_loss: 0.0112 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0138 - sparse_categorical_accuracy: 0.9963 - val_loss: 0.0818 - val_sparse_categorical_accuracy: 0.9696
# Epoch 38/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0150 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.0160 - val_sparse_categorical_accuracy: 0.9953
# Epoch 39/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0125 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0203 - val_sparse_categorical_accuracy: 0.9953
# Epoch 40/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0158 - sparse_categorical_accuracy: 0.9953 - val_loss: 0.0150 - val_sparse_categorical_accuracy: 0.9953
# Epoch 41/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0145 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0089 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0255 - val_sparse_categorical_accuracy: 0.9930
# Epoch 43/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0093 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.0019 - val_sparse_categorical_accuracy: 1.0000
# Epoch 44/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0115 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.0048 - val_sparse_categorical_accuracy: 1.0000
# Epoch 45/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0146 - sparse_categorical_accuracy: 0.9932 - val_loss: 0.0019 - val_sparse_categorical_accuracy: 1.0000
# Epoch 46/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0178 - sparse_categorical_accuracy: 0.9957 - val_loss: 0.0056 - val_sparse_categorical_accuracy: 1.0000
# Epoch 47/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0090 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0043 - val_sparse_categorical_accuracy: 1.0000
# Epoch 48/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0112 - sparse_categorical_accuracy: 0.9959 - val_loss: 0.0027 - val_sparse_categorical_accuracy: 1.0000
# Epoch 49/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0293 - sparse_categorical_accuracy: 0.9882 - val_loss: 0.0335 - val_sparse_categorical_accuracy: 0.9860
# Epoch 50/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0104 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.0475 - val_sparse_categorical_accuracy: 0.9836
# Epoch 51/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0092 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.0051 - val_sparse_categorical_accuracy: 1.0000
# Epoch 52/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0219 - sparse_categorical_accuracy: 0.9919 - val_loss: 0.0043 - val_sparse_categorical_accuracy: 1.0000
# Epoch 53/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0084 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0048 - val_sparse_categorical_accuracy: 1.0000
# Epoch 54/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0076 - sparse_categorical_accuracy: 0.9963 - val_loss: 0.0046 - val_sparse_categorical_accuracy: 1.0000
# Epoch 55/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0310 - sparse_categorical_accuracy: 0.9867 - val_loss: 0.0633 - val_sparse_categorical_accuracy: 0.9720
# Epoch 56/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0298 - sparse_categorical_accuracy: 0.9930 - val_loss: 0.1047 - val_sparse_categorical_accuracy: 0.9509
# Epoch 57/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0099 - sparse_categorical_accuracy: 0.9961 - val_loss: 0.1725 - val_sparse_categorical_accuracy: 0.9136
# Epoch 58/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0081 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.1620 - val_sparse_categorical_accuracy: 0.9276
# Epoch 59/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0111 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.1504 - val_sparse_categorical_accuracy: 0.9229
# Epoch 60/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0124 - sparse_categorical_accuracy: 0.9960 - val_loss: 0.0252 - val_sparse_categorical_accuracy: 0.9930
# Epoch 61/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0106 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.2151 - val_sparse_categorical_accuracy: 0.9019
# Epoch 62/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0152 - sparse_categorical_accuracy: 0.9949 - val_loss: 0.1159 - val_sparse_categorical_accuracy: 0.9463
# Epoch 63/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0591 - sparse_categorical_accuracy: 0.9783 - val_loss: 0.0423 - val_sparse_categorical_accuracy: 0.9836
# Epoch 64/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0095 - sparse_categorical_accuracy: 0.9971 - val_loss: 0.0683 - val_sparse_categorical_accuracy: 0.9720
# Epoch 65/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0094 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.0057 - val_sparse_categorical_accuracy: 1.0000
# Epoch 66/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0133 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.0099 - val_sparse_categorical_accuracy: 0.9977
# Epoch 67/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0092 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0153 - val_sparse_categorical_accuracy: 0.9953
# Epoch 68/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0086 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.0172 - val_sparse_categorical_accuracy: 0.9953
# Epoch 69/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0088 - sparse_categorical_accuracy: 0.9966 - val_loss: 0.0148 - val_sparse_categorical_accuracy: 0.9953
# Epoch 70/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - sparse_categorical_accuracy: 0.9974 - val_loss: 0.0222 - val_sparse_categorical_accuracy: 0.9953
# Epoch 71/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0101 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.1370 - val_sparse_categorical_accuracy: 0.9393
# Epoch 72/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0171 - sparse_categorical_accuracy: 0.9953 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 1.0000
# Epoch 73/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.0144 - val_sparse_categorical_accuracy: 0.9953
# Epoch 74/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - sparse_categorical_accuracy: 0.9935 - val_loss: 0.0538 - val_sparse_categorical_accuracy: 0.9790
# Epoch 75/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0265 - val_sparse_categorical_accuracy: 0.9930
# Epoch 76/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0086 - sparse_categorical_accuracy: 0.9952 - val_loss: 0.0051 - val_sparse_categorical_accuracy: 1.0000
# Epoch 77/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.0019 - val_sparse_categorical_accuracy: 1.0000
# Epoch 78/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0040 - val_sparse_categorical_accuracy: 1.0000
# Epoch 79/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0094 - val_sparse_categorical_accuracy: 0.9953
# Epoch 80/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0061 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0023 - val_sparse_categorical_accuracy: 1.0000
# Epoch 81/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0037 - val_sparse_categorical_accuracy: 1.0000
# Epoch 82/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0140 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.0109 - val_sparse_categorical_accuracy: 0.9953
# Epoch 83/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0019 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.0017 - val_sparse_categorical_accuracy: 1.0000
# Epoch 84/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0266 - sparse_categorical_accuracy: 0.9892 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 1.0000
# Epoch 85/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0135 - sparse_categorical_accuracy: 0.9959 - val_loss: 0.0049 - val_sparse_categorical_accuracy: 1.0000
# Epoch 86/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0067 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0014 - val_sparse_categorical_accuracy: 1.0000
# Epoch 87/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0063 - sparse_categorical_accuracy: 0.9968 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 88/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0021 - sparse_categorical_accuracy: 0.9999 - val_loss: 9.9223e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 89/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0066 - sparse_categorical_accuracy: 0.9988 - val_loss: 4.4467e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 90/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0313 - sparse_categorical_accuracy: 0.9883 - val_loss: 0.0356 - val_sparse_categorical_accuracy: 0.9860
# Epoch 91/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.0205 - val_sparse_categorical_accuracy: 0.9883
# Epoch 92/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0154 - val_sparse_categorical_accuracy: 0.9883
# Epoch 93/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0161 - sparse_categorical_accuracy: 0.9906 - val_loss: 0.1019 - val_sparse_categorical_accuracy: 0.9603
# Epoch 94/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0048 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0115 - val_sparse_categorical_accuracy: 0.9907
# Epoch 95/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - sparse_categorical_accuracy: 0.9959 - val_loss: 0.0075 - val_sparse_categorical_accuracy: 0.9977
# Epoch 96/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0137 - sparse_categorical_accuracy: 0.9938 - val_loss: 7.0106e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 97/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0017 - val_sparse_categorical_accuracy: 1.0000
# Epoch 98/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0088 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.0015 - val_sparse_categorical_accuracy: 1.0000
# Epoch 99/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9995 - val_loss: 7.4395e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 100/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 101/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0166 - sparse_categorical_accuracy: 0.9941 - val_loss: 6.0508e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 102/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - sparse_categorical_accuracy: 0.9976 - val_loss: 6.6904e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 103/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0130 - sparse_categorical_accuracy: 0.9954 - val_loss: 9.1785e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 104/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0136 - sparse_categorical_accuracy: 0.9912 - val_loss: 6.7903e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 105/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 106/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0083 - sparse_categorical_accuracy: 0.9956 - val_loss: 0.0636 - val_sparse_categorical_accuracy: 0.9720
# Epoch 107/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - sparse_categorical_accuracy: 0.9966 - val_loss: 0.0708 - val_sparse_categorical_accuracy: 0.9696
# Epoch 108/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - sparse_categorical_accuracy: 0.9984 - val_loss: 6.6438e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 109/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0067 - sparse_categorical_accuracy: 0.9970 - val_loss: 8.5205e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 110/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0047 - sparse_categorical_accuracy: 0.9998 - val_loss: 8.2078e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 111/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.0072 - val_sparse_categorical_accuracy: 0.9953
# Epoch 112/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 1.0000
# Epoch 113/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0549 - val_sparse_categorical_accuracy: 0.9813
# Epoch 114/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0165 - sparse_categorical_accuracy: 0.9956 - val_loss: 0.0188 - val_sparse_categorical_accuracy: 0.9883
# Epoch 115/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0087 - sparse_categorical_accuracy: 0.9966 - val_loss: 0.0020 - val_sparse_categorical_accuracy: 1.0000
# Epoch 116/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0062 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0056 - val_sparse_categorical_accuracy: 0.9977
# Epoch 117/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0189 - sparse_categorical_accuracy: 0.9923 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 118/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0067 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.0019 - val_sparse_categorical_accuracy: 1.0000
# Epoch 119/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0331 - sparse_categorical_accuracy: 0.9853 - val_loss: 4.7523e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 120/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0132 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 121/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0120 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.0019 - val_sparse_categorical_accuracy: 1.0000
# Epoch 122/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0109 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.0046 - val_sparse_categorical_accuracy: 1.0000
# Epoch 123/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0063 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0230 - val_sparse_categorical_accuracy: 0.9883
# Epoch 124/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023 - sparse_categorical_accuracy: 0.9999 - val_loss: 3.7196e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 125/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - sparse_categorical_accuracy: 1.0000 - val_loss: 9.1160e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 126/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - sparse_categorical_accuracy: 0.9990 - val_loss: 4.8037e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 127/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9978 - val_loss: 8.2707e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 128/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0211 - sparse_categorical_accuracy: 0.9921 - val_loss: 0.0039 - val_sparse_categorical_accuracy: 1.0000
# Epoch 129/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0016 - val_sparse_categorical_accuracy: 1.0000
# Epoch 130/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9984 - val_loss: 2.1030e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 131/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0095 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0033 - val_sparse_categorical_accuracy: 1.0000
# Epoch 132/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - sparse_categorical_accuracy: 0.9996 - val_loss: 3.2730e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 133/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0030 - val_sparse_categorical_accuracy: 1.0000
# Epoch 134/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - sparse_categorical_accuracy: 0.9954 - val_loss: 4.2061e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 135/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0069 - sparse_categorical_accuracy: 0.9980 - val_loss: 3.2689e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 136/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9980 - val_loss: 3.0654e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 137/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0085 - sparse_categorical_accuracy: 0.9964 - val_loss: 6.0373e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 138/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0100 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.0794 - val_sparse_categorical_accuracy: 0.9673
# Epoch 139/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0498 - val_sparse_categorical_accuracy: 0.9766
# Epoch 140/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - sparse_categorical_accuracy: 0.9926 - val_loss: 0.0234 - val_sparse_categorical_accuracy: 0.9883
# Epoch 141/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0090 - sparse_categorical_accuracy: 0.9945 - val_loss: 4.8897e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 142/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0060 - sparse_categorical_accuracy: 0.9993 - val_loss: 3.4898e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 143/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0195 - sparse_categorical_accuracy: 0.9960 - val_loss: 0.0068 - val_sparse_categorical_accuracy: 0.9977
# Epoch 144/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.0055 - val_sparse_categorical_accuracy: 0.9977
# Epoch 145/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0075 - sparse_categorical_accuracy: 0.9971 - val_loss: 0.0024 - val_sparse_categorical_accuracy: 1.0000
# Epoch 146/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0135 - sparse_categorical_accuracy: 0.9947 - val_loss: 0.0470 - val_sparse_categorical_accuracy: 0.9860
# Epoch 147/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0038 - val_sparse_categorical_accuracy: 1.0000
# Epoch 148/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - sparse_categorical_accuracy: 0.9998 - val_loss: 3.0915e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 149/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0182 - sparse_categorical_accuracy: 0.9940 - val_loss: 0.0577 - val_sparse_categorical_accuracy: 0.9766
# Epoch 150/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0024 - val_sparse_categorical_accuracy: 1.0000
# Epoch 151/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0085 - val_sparse_categorical_accuracy: 0.9953
# Epoch 152/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0076 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.0059 - val_sparse_categorical_accuracy: 0.9977
# Epoch 153/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 154/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0083 - sparse_categorical_accuracy: 0.9960 - val_loss: 5.2314e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 155/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0064 - sparse_categorical_accuracy: 0.9973 - val_loss: 6.8778e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 156/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9987 - val_loss: 4.6225e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 157/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0101 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.0478 - val_sparse_categorical_accuracy: 0.9836
# Epoch 158/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0095 - sparse_categorical_accuracy: 0.9959 - val_loss: 0.0053 - val_sparse_categorical_accuracy: 0.9977
# Epoch 159/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0033 - val_sparse_categorical_accuracy: 1.0000
# Epoch 160/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0014 - val_sparse_categorical_accuracy: 1.0000
# Epoch 161/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9991 - val_loss: 3.4381e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 162/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0055 - sparse_categorical_accuracy: 0.9994 - val_loss: 4.7336e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 163/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9985 - val_loss: 4.4479e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 164/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9961 - val_loss: 3.5777e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 165/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0113 - sparse_categorical_accuracy: 0.9968 - val_loss: 0.0499 - val_sparse_categorical_accuracy: 0.9836
# Epoch 166/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9994 - val_loss: 8.6353e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 167/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0158 - sparse_categorical_accuracy: 0.9927 - val_loss: 0.0062 - val_sparse_categorical_accuracy: 1.0000
# Epoch 168/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9988 - val_loss: 4.1178e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 169/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9997 - val_loss: 2.5149e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 170/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0023 - sparse_categorical_accuracy: 0.9999 - val_loss: 1.9602e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 171/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0078 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0022 - val_sparse_categorical_accuracy: 1.0000
# Epoch 172/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0150 - sparse_categorical_accuracy: 0.9930 - val_loss: 0.0515 - val_sparse_categorical_accuracy: 0.9766
# Epoch 173/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9994 - val_loss: 2.9602e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 174/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - sparse_categorical_accuracy: 0.9960 - val_loss: 0.0201 - val_sparse_categorical_accuracy: 0.9883
# Epoch 175/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0025 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.0220 - val_sparse_categorical_accuracy: 0.9883
# Epoch 176/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0067 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0080 - val_sparse_categorical_accuracy: 0.9977
# Epoch 177/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0055 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0044 - val_sparse_categorical_accuracy: 1.0000
# Epoch 178/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0173 - val_sparse_categorical_accuracy: 0.9907
# Epoch 179/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - sparse_categorical_accuracy: 0.9995 - val_loss: 5.8045e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 180/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.0026 - val_sparse_categorical_accuracy: 1.0000
# Epoch 181/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0132 - sparse_categorical_accuracy: 0.9951 - val_loss: 6.9718e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 182/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.0051 - val_sparse_categorical_accuracy: 0.9977
# Epoch 183/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0097 - sparse_categorical_accuracy: 0.9961 - val_loss: 3.3567e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 184/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0063 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 185/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0082 - sparse_categorical_accuracy: 0.9971 - val_loss: 0.0023 - val_sparse_categorical_accuracy: 1.0000
# Epoch 186/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0016 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 187/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0656 - val_sparse_categorical_accuracy: 0.9720
# Epoch 188/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.0261 - val_sparse_categorical_accuracy: 0.9883
# Epoch 189/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0082 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.4813 - val_sparse_categorical_accuracy: 0.8972
# Epoch 190/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0060 - sparse_categorical_accuracy: 0.9966 - val_loss: 0.1195 - val_sparse_categorical_accuracy: 0.9626
# Epoch 191/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0059 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0864 - val_sparse_categorical_accuracy: 0.9650
# Epoch 192/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 1.0000
# Epoch 193/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0034 - val_sparse_categorical_accuracy: 1.0000
# Epoch 194/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0168 - sparse_categorical_accuracy: 0.9922 - val_loss: 0.2781 - val_sparse_categorical_accuracy: 0.9346
# Epoch 195/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0101 - sparse_categorical_accuracy: 0.9941 - val_loss: 0.2678 - val_sparse_categorical_accuracy: 0.9416
# Epoch 196/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0022 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.0317 - val_sparse_categorical_accuracy: 0.9883
# Epoch 197/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0072 - sparse_categorical_accuracy: 0.9965 - val_loss: 3.1528e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 198/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0145 - val_sparse_categorical_accuracy: 0.9953
# Epoch 199/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0019 - sparse_categorical_accuracy: 0.9997 - val_loss: 1.8252e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 200/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0122 - sparse_categorical_accuracy: 0.9945 - val_loss: 2.0732e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 201/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9965 - val_loss: 2.7630e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 202/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9994 - val_loss: 2.1903e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 203/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0025 - val_sparse_categorical_accuracy: 1.0000
# Epoch 204/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0096 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.5431 - val_sparse_categorical_accuracy: 0.8855
# Epoch 205/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0093 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0284 - val_sparse_categorical_accuracy: 0.9860
# Epoch 206/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0025 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0061 - val_sparse_categorical_accuracy: 0.9977
# Epoch 207/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0023 - sparse_categorical_accuracy: 0.9996 - val_loss: 0.0060 - val_sparse_categorical_accuracy: 0.9977
# Epoch 208/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0110 - sparse_categorical_accuracy: 0.9969 - val_loss: 7.3776e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 209/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9998 - val_loss: 5.5054e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 210/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0060 - sparse_categorical_accuracy: 0.9971 - val_loss: 0.0112 - val_sparse_categorical_accuracy: 0.9930
# Epoch 211/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0182 - sparse_categorical_accuracy: 0.9928 - val_loss: 0.1763 - val_sparse_categorical_accuracy: 0.9533
# Epoch 212/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0179 - sparse_categorical_accuracy: 0.9941 - val_loss: 0.3861 - val_sparse_categorical_accuracy: 0.9229
# Epoch 213/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.2010 - val_sparse_categorical_accuracy: 0.9463
# Epoch 214/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0306 - val_sparse_categorical_accuracy: 0.9836
# Epoch 215/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0141 - sparse_categorical_accuracy: 0.9971 - val_loss: 0.0065 - val_sparse_categorical_accuracy: 0.9977
# Epoch 216/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0073 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0338 - val_sparse_categorical_accuracy: 0.9813
# Epoch 217/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0020 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0063 - val_sparse_categorical_accuracy: 0.9977
# Epoch 218/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.0114 - val_sparse_categorical_accuracy: 0.9953
# Epoch 219/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0064 - sparse_categorical_accuracy: 0.9980 - val_loss: 4.2764e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 220/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0571 - sparse_categorical_accuracy: 0.9842 - val_loss: 0.0318 - val_sparse_categorical_accuracy: 0.9883
# Epoch 221/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0053 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.4627 - val_sparse_categorical_accuracy: 0.9252
# Epoch 222/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.0874 - val_sparse_categorical_accuracy: 0.9650
# Epoch 223/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0203 - sparse_categorical_accuracy: 0.9910 - val_loss: 0.5004 - val_sparse_categorical_accuracy: 0.9089
# Epoch 224/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.5415 - val_sparse_categorical_accuracy: 0.8902
# Epoch 225/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0115 - sparse_categorical_accuracy: 0.9959 - val_loss: 0.0033 - val_sparse_categorical_accuracy: 1.0000
# Epoch 226/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0274 - sparse_categorical_accuracy: 0.9922 - val_loss: 0.0059 - val_sparse_categorical_accuracy: 0.9977
# Epoch 227/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0059 - sparse_categorical_accuracy: 0.9971 - val_loss: 0.0057 - val_sparse_categorical_accuracy: 1.0000
# Epoch 228/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0078 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.0116 - val_sparse_categorical_accuracy: 0.9953
# Epoch 229/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0115 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0079 - val_sparse_categorical_accuracy: 0.9977
# Epoch 230/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.0141 - val_sparse_categorical_accuracy: 0.9930
# Epoch 231/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0092 - sparse_categorical_accuracy: 0.9966 - val_loss: 0.0270 - val_sparse_categorical_accuracy: 0.9883
# Epoch 232/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.0307 - val_sparse_categorical_accuracy: 0.9883
# Epoch 233/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0025 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0019 - val_sparse_categorical_accuracy: 1.0000
# Epoch 234/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9987 - val_loss: 2.9435e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 235/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0042 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.4500e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 236/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9973 - val_loss: 6.0310e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 237/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0075 - sparse_categorical_accuracy: 0.9972 - val_loss: 2.0310e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 238/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0127 - sparse_categorical_accuracy: 0.9949 - val_loss: 0.0033 - val_sparse_categorical_accuracy: 1.0000
# Epoch 239/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0184 - sparse_categorical_accuracy: 0.9930 - val_loss: 3.5736e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 240/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0080 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 1.0000
# Epoch 241/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0076 - sparse_categorical_accuracy: 0.9960 - val_loss: 0.0433 - val_sparse_categorical_accuracy: 0.9743
# Epoch 242/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0088 - val_sparse_categorical_accuracy: 0.9977
# Epoch 243/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9986 - val_loss: 4.8363e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 244/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0055 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0019 - val_sparse_categorical_accuracy: 1.0000
# Epoch 245/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0011 - val_sparse_categorical_accuracy: 1.0000
# Epoch 246/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 1.0000
# Epoch 247/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023 - sparse_categorical_accuracy: 0.9995 - val_loss: 2.2124e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 248/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0229 - val_sparse_categorical_accuracy: 0.9907
# Epoch 249/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.0171 - val_sparse_categorical_accuracy: 0.9930
# Epoch 250/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - sparse_categorical_accuracy: 0.9992 - val_loss: 9.5523e-05 - val_sparse_categorical_accuracy: 1.0000
# Epoch 251/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0086 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.0956 - val_sparse_categorical_accuracy: 0.9650
# Epoch 252/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.1487 - val_sparse_categorical_accuracy: 0.9509
# Epoch 253/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0166 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.1000 - val_sparse_categorical_accuracy: 0.9626
# Epoch 254/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0019 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 1.0000
# Epoch 255/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0061 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.0039 - val_sparse_categorical_accuracy: 1.0000
# Epoch 256/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0081 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.0051 - val_sparse_categorical_accuracy: 0.9977
# Epoch 257/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0046 - val_sparse_categorical_accuracy: 1.0000
# Epoch 258/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0078 - val_sparse_categorical_accuracy: 0.9977
# Epoch 259/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0109 - val_sparse_categorical_accuracy: 0.9977
# Epoch 260/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0098 - sparse_categorical_accuracy: 0.9959 - val_loss: 4.1242e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 261/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0055 - sparse_categorical_accuracy: 0.9982 - val_loss: 4.7656e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 262/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0082 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0064 - val_sparse_categorical_accuracy: 0.9977
# Epoch 263/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0018 - sparse_categorical_accuracy: 0.9996 - val_loss: 6.2230e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 264/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0098 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0295 - val_sparse_categorical_accuracy: 0.9883
# Epoch 265/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0110 - sparse_categorical_accuracy: 0.9959 - val_loss: 0.1430 - val_sparse_categorical_accuracy: 0.9603
# Epoch 266/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0094 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.1547 - val_sparse_categorical_accuracy: 0.9486
# Epoch 267/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0022 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.0051 - val_sparse_categorical_accuracy: 1.0000
# Epoch 268/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0056 - sparse_categorical_accuracy: 0.9985 - val_loss: 2.2362e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 269/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - sparse_categorical_accuracy: 0.9988 - val_loss: 1.6084e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 270/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0128 - sparse_categorical_accuracy: 0.9957 - val_loss: 2.7692e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 271/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0519 - sparse_categorical_accuracy: 0.9911 - val_loss: 0.0033 - val_sparse_categorical_accuracy: 1.0000
# Epoch 272/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0075 - sparse_categorical_accuracy: 0.9973 - val_loss: 2.5608e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 273/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0089 - sparse_categorical_accuracy: 0.9963 - val_loss: 0.0732 - val_sparse_categorical_accuracy: 0.9720
# Epoch 274/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0023 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0126 - val_sparse_categorical_accuracy: 0.9930
# Epoch 275/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0125 - val_sparse_categorical_accuracy: 0.9953
# Epoch 276/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0169 - sparse_categorical_accuracy: 0.9971 - val_loss: 0.0304 - val_sparse_categorical_accuracy: 0.9860
# Epoch 277/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - sparse_categorical_accuracy: 0.9991 - val_loss: 4.3814e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 278/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0163 - sparse_categorical_accuracy: 0.9938 - val_loss: 3.2140e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 279/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.0074 - val_sparse_categorical_accuracy: 0.9977
# Epoch 280/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.0019 - val_sparse_categorical_accuracy: 1.0000
# Epoch 281/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 282/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - sparse_categorical_accuracy: 0.9997 - val_loss: 5.7085e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 283/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0300 - val_sparse_categorical_accuracy: 0.9836
# Epoch 284/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0027 - sparse_categorical_accuracy: 1.0000 - val_loss: 4.9222e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 285/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0126 - sparse_categorical_accuracy: 0.9940 - val_loss: 0.0873 - val_sparse_categorical_accuracy: 0.9673
# Epoch 286/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0155 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0165 - val_sparse_categorical_accuracy: 0.9883
# Epoch 287/500
# ...
# Epoch 407/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0114 - sparse_categorical_accuracy: 0.9961 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 1.0000
# Epoch 408/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7313e-04 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.0013 - val_sparse_categorical_accuracy: 1.0000
# Epoch 409/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - sparse_categorical_accuracy: 0.9986 - val_loss: 7.4556e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 410/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0060 - sparse_categorical_accuracy: 0.9959 - val_loss: 0.0663 - val_sparse_categorical_accuracy: 0.9743
# Epoch 411/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0402 - val_sparse_categorical_accuracy: 0.9836
# Epoch 412/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9984 - val_loss: 6.7012e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 413/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014 - sparse_categorical_accuracy: 0.9996 - val_loss: 1.2156e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 414/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - sparse_categorical_accuracy: 0.9996 - val_loss: 2.4770e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 415/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0200 - val_sparse_categorical_accuracy: 0.9907
# Epoch 416/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6604e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0020 - val_sparse_categorical_accuracy: 1.0000
# Epoch 417/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0271 - val_sparse_categorical_accuracy: 0.9860
# Epoch 418/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.1601 - val_sparse_categorical_accuracy: 0.9533
# Epoch 419/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0149 - sparse_categorical_accuracy: 0.9963 - val_loss: 0.0184 - val_sparse_categorical_accuracy: 0.9930
# Epoch 420/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.0012 - val_sparse_categorical_accuracy: 1.0000
# Epoch 421/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9985 - val_loss: 2.7336e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 422/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9985 - val_loss: 1.4136e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 423/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0050 - val_sparse_categorical_accuracy: 0.9977
# Epoch 424/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.0100 - val_sparse_categorical_accuracy: 0.9953
# Epoch 425/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.0033 - val_sparse_categorical_accuracy: 1.0000
# Epoch 426/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0087 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.0147 - val_sparse_categorical_accuracy: 0.9907
# Epoch 427/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0637 - val_sparse_categorical_accuracy: 0.9743
# Epoch 428/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.2098 - val_sparse_categorical_accuracy: 0.9486
# Epoch 429/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0052 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.4921 - val_sparse_categorical_accuracy: 0.9112
# Epoch 430/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0019 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.2423 - val_sparse_categorical_accuracy: 0.9393
# Epoch 431/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.1672 - val_sparse_categorical_accuracy: 0.9369
# Epoch 432/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0398 - sparse_categorical_accuracy: 0.9862 - val_loss: 0.2510 - val_sparse_categorical_accuracy: 0.9346
# Epoch 433/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9989 - val_loss: 4.3318e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 434/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0054 - sparse_categorical_accuracy: 0.9955 - val_loss: 7.7427e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 435/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0419 - val_sparse_categorical_accuracy: 0.9813
# Epoch 436/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0091 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0087 - val_sparse_categorical_accuracy: 0.9977
# Epoch 437/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.0049 - val_sparse_categorical_accuracy: 1.0000
# Epoch 438/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - sparse_categorical_accuracy: 0.9995 - val_loss: 4.0297e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 439/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - sparse_categorical_accuracy: 1.0000 - val_loss: 8.7254e-05 - val_sparse_categorical_accuracy: 1.0000
# Epoch 440/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9991 - val_loss: 1.2143e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 441/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.0636e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 9.8847e-05 - val_sparse_categorical_accuracy: 1.0000
# Epoch 442/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - sparse_categorical_accuracy: 0.9968 - val_loss: 8.3827e-05 - val_sparse_categorical_accuracy: 1.0000
# Epoch 443/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0348 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.0018 - val_sparse_categorical_accuracy: 1.0000
# Epoch 444/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0022 - sparse_categorical_accuracy: 0.9997 - val_loss: 8.0902e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 445/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0071 - sparse_categorical_accuracy: 0.9957 - val_loss: 1.8651e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 446/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015 - sparse_categorical_accuracy: 0.9999 - val_loss: 2.4581e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 447/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0074 - sparse_categorical_accuracy: 0.9975 - val_loss: 1.5090e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 448/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0025 - sparse_categorical_accuracy: 0.9988 - val_loss: 2.5530e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 449/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0057 - sparse_categorical_accuracy: 0.9973 - val_loss: 2.2285e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 450/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0095 - sparse_categorical_accuracy: 0.9972 - val_loss: 1.3496e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 451/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7277e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.3262e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 452/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - sparse_categorical_accuracy: 0.9999 - val_loss: 1.6074e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 453/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016 - sparse_categorical_accuracy: 0.9997 - val_loss: 1.0608e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 454/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - sparse_categorical_accuracy: 0.9996 - val_loss: 0.0015 - val_sparse_categorical_accuracy: 1.0000
# Epoch 455/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0053 - sparse_categorical_accuracy: 0.9974 - val_loss: 0.0032 - val_sparse_categorical_accuracy: 1.0000
# Epoch 456/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0053 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.0010 - val_sparse_categorical_accuracy: 1.0000
# Epoch 457/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0081 - val_sparse_categorical_accuracy: 0.9953
# Epoch 458/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - sparse_categorical_accuracy: 1.0000 - val_loss: 8.2354e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 459/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0023 - sparse_categorical_accuracy: 0.9995 - val_loss: 9.1713e-05 - val_sparse_categorical_accuracy: 1.0000
# Epoch 460/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.0066 - val_sparse_categorical_accuracy: 0.9977
# Epoch 461/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - sparse_categorical_accuracy: 0.9999 - val_loss: 5.4076e-05 - val_sparse_categorical_accuracy: 1.0000
# Epoch 462/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9980 - val_loss: 1.0839e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 463/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.0040 - val_sparse_categorical_accuracy: 1.0000
# Epoch 464/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0063 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0099 - val_sparse_categorical_accuracy: 0.9953
# Epoch 465/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4145e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.4306e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 466/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8229e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0006e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 467/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.3352e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.5465e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 468/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0055 - sparse_categorical_accuracy: 0.9976 - val_loss: 5.3586e-05 - val_sparse_categorical_accuracy: 1.0000
# Epoch 469/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9981 - val_loss: 6.9175e-05 - val_sparse_categorical_accuracy: 1.0000
# Epoch 470/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0054 - sparse_categorical_accuracy: 0.9980 - val_loss: 6.2637e-05 - val_sparse_categorical_accuracy: 1.0000
# Epoch 471/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0209 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.1516 - val_sparse_categorical_accuracy: 0.9486
# Epoch 472/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.0057 - val_sparse_categorical_accuracy: 1.0000
# Epoch 473/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0079 - val_sparse_categorical_accuracy: 0.9977
# Epoch 474/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 1.0000
# Epoch 475/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.1022 - val_sparse_categorical_accuracy: 0.9650
# Epoch 476/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7705e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 1.0000
# Epoch 477/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9004e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 7.4235e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 478/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9982 - val_loss: 5.6802e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 479/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - sparse_categorical_accuracy: 0.9995 - val_loss: 2.0936e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 480/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.0016 - val_sparse_categorical_accuracy: 1.0000
# Epoch 481/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7302e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 8.7121e-05 - val_sparse_categorical_accuracy: 1.0000
# Epoch 482/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - sparse_categorical_accuracy: 0.9980 - val_loss: 8.1488e-05 - val_sparse_categorical_accuracy: 1.0000
# Epoch 483/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012 - sparse_categorical_accuracy: 0.9996 - val_loss: 9.4942e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 484/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0129 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.3655 - val_sparse_categorical_accuracy: 0.9089
# Epoch 485/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0047 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.0128 - val_sparse_categorical_accuracy: 0.9907
# Epoch 486/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0053 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0464 - val_sparse_categorical_accuracy: 0.9813
# Epoch 487/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0053 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0261 - val_sparse_categorical_accuracy: 0.9860
# Epoch 488/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7422e-04 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.0043 - val_sparse_categorical_accuracy: 1.0000
# Epoch 489/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - sparse_categorical_accuracy: 0.9993 - val_loss: 8.2042e-05 - val_sparse_categorical_accuracy: 1.0000
# Epoch 490/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.1467e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 6.9998e-05 - val_sparse_categorical_accuracy: 1.0000
# Epoch 491/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8863e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.0472e-04 - val_sparse_categorical_accuracy: 1.0000
# Epoch 492/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0190 - sparse_categorical_accuracy: 0.9961 - val_loss: 0.1698 - val_sparse_categorical_accuracy: 0.9533
# Epoch 493/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0337 - val_sparse_categorical_accuracy: 0.9790
# Epoch 494/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 1.0000
# Epoch 495/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0101 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.9534 - val_sparse_categorical_accuracy: 0.8762
# Epoch 496/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - sparse_categorical_accuracy: 0.9965 - val_loss: 1.8629 - val_sparse_categorical_accuracy: 0.7360
# Epoch 497/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0795 - val_sparse_categorical_accuracy: 0.9720
# Epoch 498/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0076 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0087 - val_sparse_categorical_accuracy: 0.9977
# Epoch 499/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.0421 - val_sparse_categorical_accuracy: 0.9836
# Epoch 500/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0093 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.5030 - val_sparse_categorical_accuracy: 0.8879

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df[['loss', 'val_loss']].plot()
# Out:
# <Axes: >

# %%
loss_df[['sparse_categorical_accuracy', 'val_sparse_categorical_accuracy']].plot()
# Out:
# <Axes: >

# %%
# compare the final model loss/accuracy/evaluation values
# the values should again match mostly
print("Test data evaluation:")
print(model.evaluate(x_test, y_test, verbose=0))
print("\nTrain data evaluation:")
print(model.evaluate(x_train, y_train, verbose=0))
# Out:
# Test data evaluation:
# [0.5059933662414551, 0.8898582458496094]
#
# Train data evaluation:
# [0.5335965156555176, 0.8895648121833801]

# %%
# get predictions and convert with argmax() to get categories 
# instead of raw probabilities
test_predictions = model.predict(x_test)
test_predictions = np.argmax(test_predictions, axis=1)
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
# confusion matrix
import seaborn as sns
sns.heatmap(confusion_matrix(y_test, test_predictions), annot=True, fmt='g')
# Out:
# <Axes: >

# %%
# print the classification report based on true values and predictions
print(classification_report(y_test, test_predictions))

# get overall accuracy of the model and print it
acc = accuracy_score(y_test, test_predictions)
print("\nModel overall accuracy: {:.2f}%".format(acc * 100))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.88       456
#            1       0.82      1.00      0.90       461
#
#     accuracy                           0.89       917
#    macro avg       0.91      0.89      0.89       917
# weighted avg       0.91      0.89      0.89       917
#
#
# Model overall accuracy: 88.99%

# %% [markdown]
# <b>Test the model with some imaginary/synthetic signal examples from ChatGPT</b>

# %%
signal_index = 8
print(y_test[signal_index])
print(class_names[y_test[signal_index]])

plt.figure()
plt.plot(x_test[signal_index])
plt.show()
# Out:
# 1
# wind_speed

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create x values from 0 to 49
x = np.arange(50)

# Create y values that fluctuate around 0.2
np.random.seed(0)  # For reproducibility
y = 0.2 + np.random.normal(0, 0.05, size=x.shape)

# Introduce spikes
y[15:20] += 0.3  # First spike
y[35:40] += 0.3  # Second spike

# Optional: Clip y values to avoid extreme outliers
y = np.clip(y, 0, 1)

# Plot the result (optional)
plt.plot(x, y)
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Y values fluctuating around 0.2 with spikes')
plt.show()

# y now contains the desired values

# %%
points = y
test_signal = np.expand_dims(points, axis=1)
test_batch = np.array([test_signal])

test_predict = model.predict(test_batch)
print(test_predict)

index = np.argmax(test_predict)
print(class_names[index])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# [[4.8649235e-10 1.0000000e+00]]
# wind_speed

# %%
signal_index = 22
print(y_test[signal_index])
print(class_names[y_test[signal_index]])

plt.figure()
plt.plot(x_test[signal_index])
plt.show()
# Out:
# 0
# meantemp

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create x values from 0 to 49
x = np.arange(50)

# Create y values that fluctuate around 0.5
np.random.seed(0)  # For reproducibility
y = 0.5 + np.random.normal(0, 0.05, size=x.shape)

# Introduce a valley around the middle (indices 20 to 30)
y[14:36] -= 0.2 + np.random.normal(0, 0.02, size=22)  # Valley around 0.2

# Optional: Clip y values to avoid extreme outliers
y = np.clip(y, 0, 1)

# Plot the result (optional)
plt.plot(x, y)
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Y values fluctuating around 0.5 with a valley')
plt.show()

# y now contains the desired values

# %%
points = y
test_signal = np.expand_dims(points, axis=1)
test_batch = np.array([test_signal])

test_predict = model.predict(test_batch)
print(test_predict)

index = np.argmax(test_predict)
print(class_names[index])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# [[3.1134464e-06 9.9999690e-01]]
# wind_speed
