# %%
import pandas as pd
import numpy as np

#Reports
from ydata_profiling import ProfileReport
from autoviz.AutoViz_Class import AutoViz_Class
import sweetviz as sv
import phik
import shap


from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

#Class
import keras
from keras import layers
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
import tensorflow as tf
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %% [markdown]
# <b>Data Frame</b>

# %%
df = pd.read_csv("Clean_Zillow.csv")
df.head()
# Out:
#    longitude  countyFIPS  monthlyHoaFee  annualHomeownersInsurance state  \
# 0 -149.90807    2020.0         0.0                 2840              AK
# 1 -149.90822    2020.0         0.0                 2934              AK
# 2 -149.90833    2020.0         0.0                 4187              AK
# 3 -149.90834    2020.0         0.0                 2920              AK
# 4 -149.90749    2020.0         0.0                 4100              AK
#
#    yearBuilt  latitude   rentZestimate    city     zestimateLowPercent  \
# 0   1959.0    61.217308     3142.0      Anchorage         12.0
# 1   1961.0    61.217136     3113.0      Anchorage         12.0
# 2   1983.0    61.217000     4282.0      Anchorage         12.0
# 3   1947.0    61.216720     3458.0      Anchorage         15.0
# 4   2000.0    61.217120     4161.0      Anchorage         18.0
#
#    timeOnZillow  zestimate  livingArea  zipcode  propertyTaxRate  bathrooms  \
# 0     3609.0     676100.0     2668.0     99501        1.31           2.0
# 1     2098.0     698600.0     3179.0     99501        1.31           2.0
# 2     3758.0     996800.0     3059.0     99501        1.31           3.0
# 3     3543.0     695300.0     1642.0     99501        1.31           2.0
# 4     3953.0     976100.0     4483.0     99501        1.31           4.0
#
#    bedrooms   price  zestimateHighPercent  homeType_APARTMENT  homeType_CONDO  \
# 0     3.0    676100          13.0                   0                 0
# 1     3.0    698600          13.0                   0                 0
# 2     4.0    996800          14.0                   0                 0
# 3     5.0    695300          16.0                   0                 0
# 4     4.0    976100          24.0                   0                 1
#
#    homeType_LOT  homeType_MANUFACTURED  homeType_MULTI_FAMILY  \
# 0        0                 0                      0
# 1        0                 0                      0
# 2        0                 0                      0
# 3        0                 0                      0
# 4        0                 0                      0
#
#    homeType_SINGLE_FAMILY
# 0             1
# 1             1
# 2             1
# 3             1
# 4             0

# %% [markdown]
# <b>Y Data</b>

# %%
report = ProfileReport(df, title='Zillow Data')
report.to_file("ydata_Zillow.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# <b>AutoViz</b>

# %%
AV = AutoViz_Class()
reg_av=report = AV.AutoViz("Clean_Zillow.csv")
# Out:
# Shape of your Data Set loaded: (4943, 25)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  14
#     Number of Integer-Categorical Columns =  3
#     Number of String-Categorical Columns =  2
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  6
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     25 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_146a0_row0_col0, #T_146a0_row0_col2, #T_146a0_row0_col3, #T_146a0_row0_col4, #T_146a0_row0_col5, #T_146a0_row1_col0, #T_146a0_row1_col2, #T_146a0_row1_col3, #T_146a0_row1_col4, #T_146a0_row1_col5, #T_146a0_row2_col0, #T_146a0_row2_col2, #T_146a0_row2_col3, #T_146a0_row2_col4, #T_146a0_row2_col5, #T_146a0_row3_col0, #T_146a0_row3_col2, #T_146a0_row3_col3, #T_146a0_row3_col4, #T_146a0_row3_col5, #T_146a0_row4_col0, #T_146a0_row4_col2, #T_146a0_row4_col3, #T_146a0_row4_col4, #T_146a0_row4_col5, #T_146a0_row5_col0, #T_146a0_row5_col2, #T_146a0_row5_col3, #T_146a0_row5_col4, #T_146a0_row5_col5, #T_146a0_row6_col0, #T_146a0_row6_col2, #T_146a0_row6_col3, #T_146a0_row6_col4, #T_146a0_row6_col5, #T_146a0_row7_col0, #T_146a0_row7_col2, #T_146a0_row7_col3, #T_146a0_row7_col4, #T_146a0_row7_col5, #T_146a0_row8_col0, #T_146a0_row8_col2, #T_146a0_row8_col3, #T_146a0_row8_col4, #T_146a0_row8_col5, #T_146a0_row9_col0, #T_146a0_row9_col2, #T_146a0_row9_col3, #T_146a0_row9_col4, #T_146a0_row9_col5, #T_146a0_row10_col0, #T_146a0_row10_col2, #T_146a0_row10_col3, #T_146a0_row10_col4, #T_146a0_row10_col5, #T_146a0_row11_col0, #T_146a0_row11_col2, #T_146a0_row11_col3, #T_146a0_row11_col4, #T_146a0_row11_col5, #T_146a0_row12_col0, #T_146a0_row12_col2, #T_146a0_row12_col3, #T_146a0_row12_col4, #T_146a0_row12_col5, #T_146a0_row13_col0, #T_146a0_row13_col2, #T_146a0_row13_col3, #T_146a0_row13_col4, #T_146a0_row13_col5, #T_146a0_row14_col0, #T_146a0_row14_col2, #T_146a0_row14_col3, #T_146a0_row14_col4, #T_146a0_row14_col5, #T_146a0_row15_col0, #T_146a0_row15_col2, #T_146a0_row15_col3, #T_146a0_row15_col4, #T_146a0_row15_col5, #T_146a0_row16_col0, #T_146a0_row16_col2, #T_146a0_row16_col3, #T_146a0_row16_col4, #T_146a0_row16_col5, #T_146a0_row17_col0, #T_146a0_row17_col2, #T_146a0_row17_col3, #T_146a0_row17_col4, #T_146a0_row17_col5, #T_146a0_row18_col0, #T_146a0_row18_col2, #T_146a0_row18_col3, #T_146a0_row18_col4, #T_146a0_row18_col5, #T_146a0_row19_col0, #T_146a0_row19_col2, #T_146a0_row19_col3, #T_146a0_row19_col4, #T_146a0_row19_col5, #T_146a0_row20_col0, #T_146a0_row20_col2, #T_146a0_row20_col3, #T_146a0_row20_col4, #T_146a0_row20_col5, #T_146a0_row21_col0, #T_146a0_row21_col2, #T_146a0_row21_col3, #T_146a0_row21_col4, #T_146a0_row21_col5, #T_146a0_row22_col0, #T_146a0_row22_col2, #T_146a0_row22_col3, #T_146a0_row22_col4, #T_146a0_row22_col5, #T_146a0_row23_col0, #T_146a0_row23_col2, #T_146a0_row23_col3, #T_146a0_row23_col4, #T_146a0_row23_col5, #T_146a0_row24_col0, #T_146a0_row24_col2, #T_146a0_row24_col3, #T_146a0_row24_col4, #T_146a0_row24_col5 {
#   font-family: Segoe UI;
# }
# #T_146a0_row0_col1, #T_146a0_row1_col1, #T_146a0_row2_col1, #T_146a0_row3_col1, #T_146a0_row4_col1, #T_146a0_row5_col1, #T_146a0_row6_col1, #T_146a0_row7_col1, #T_146a0_row8_col1, #T_146a0_row9_col1, #T_146a0_row10_col1, #T_146a0_row11_col1, #T_146a0_row12_col1, #T_146a0_row13_col1, #T_146a0_row14_col1, #T_146a0_row15_col1, #T_146a0_row16_col1, #T_146a0_row17_col1, #T_146a0_row18_col1, #T_146a0_row19_col1, #T_146a0_row20_col1, #T_146a0_row21_col1, #T_146a0_row22_col1, #T_146a0_row23_col1, #T_146a0_row24_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_146a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_146a0_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_146a0_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_146a0_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_146a0_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_146a0_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_146a0_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_146a0_level0_row0" class="row_heading level0 row0" >longitude</th>
#       <td id="T_146a0_row0_col0" class="data row0 col0" >float64</td>
#       <td id="T_146a0_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_146a0_row0_col2" class="data row0 col2" >NA</td>
#       <td id="T_146a0_row0_col3" class="data row0 col3" >-150.010930</td>
#       <td id="T_146a0_row0_col4" class="data row0 col4" >-70.483100</td>
#       <td id="T_146a0_row0_col5" class="data row0 col5" >Column has 69 outliers greater than upper bound (-149.64) or lower than lower bound(-150.10). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_146a0_level0_row1" class="row_heading level0 row1" >countyFIPS</th>
#       <td id="T_146a0_row1_col0" class="data row1 col0" >float64</td>
#       <td id="T_146a0_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_146a0_row1_col2" class="data row1 col2" >NA</td>
#       <td id="T_146a0_row1_col3" class="data row1 col3" >1117.000000</td>
#       <td id="T_146a0_row1_col4" class="data row1 col4" >55079.000000</td>
#       <td id="T_146a0_row1_col5" class="data row1 col5" >Column has 68 outliers greater than upper bound (2020.00) or lower than lower bound(2020.00). Cap them or remove them., Column has a high correlation with ['longitude']. Consider dropping one of them.</td>
#     </tr>
#     <tr>
#       <th id="T_146a0_level0_row2" class="row_heading level0 row2" >monthlyHoaFee</th>
#       <td id="T_146a0_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_146a0_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_146a0_row2_col2" class="data row2 col2" >NA</td>
#       <td id="T_146a0_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_146a0_row2_col4" class="data row2 col4" >45929.000000</td>
#       <td id="T_146a0_row2_col5" class="data row2 col5" >Column has 989 outliers greater than upper bound (0.00) or lower than lower bound(0.00). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_146a0_level0_row3" class="row_heading level0 row3" >annualHomeownersInsurance</th>
#       <td id="T_146a0_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_146a0_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_146a0_row3_col2" class="data row3 col2" >41</td>
#       <td id="T_146a0_row3_col3" class="data row3 col3" >5.000000</td>
#       <td id="T_146a0_row3_col4" class="data row3 col4" >11550.000000</td>
#       <td id="T_146a0_row3_col5" class="data row3 col5" >Column has 197 outliers greater than upper bound (3062.50) or lower than lower bound(154.50). Cap them or remove them., Column has a high correlation with ['rentZestimate', 'zestimate', 'livingArea']. Consider dropping one of them.</td>
#     </tr>
#     <tr>
#       <th id="T_146a0_level0_row4" class="row_heading level0 row4" >state</th>
#       <td id="T_146a0_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_146a0_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_146a0_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_146a0_row4_col3" class="data row4 col3" ></td>
#       <td id="T_146a0_row4_col4" class="data row4 col4" ></td>
#       <td id="T_146a0_row4_col5" class="data row4 col5" >26 rare categories: Too many to list. Group them into a single category or drop the categories.</td>
#     </tr>
#     <tr>
#       <th id="T_146a0_level0_row5" class="row_heading level0 row5" >yearBuilt</th>
#       <td id="T_146a0_row5_col0" class="data row5 col0" >float64</td>
#       <td id="T_146a0_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_146a0_row5_col2" class="data row5 col2" >NA</td>
#       <td id="T_146a0_row5_col3" class="data row5 col3" >1880.000000</td>
#       <td id="T_146a0_row5_col4" class="data row5 col4" >2022.000000</td>
#       <td id="T_146a0_row5_col5" class="data row5 col5" >Column has 135 outliers greater than upper bound (2004.00) or lower than lower bound(1948.00). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_146a0_level0_row6" class="row_heading level0 row6" >latitude</th>
#       <td id="T_146a0_row6_col0" class="data row6 col0" >float64</td>
# Number of All Scatter Plots = 105
# All Plots done
# Time to run AutoViz = 17 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################

# %%
report = AV.AutoViz("Clean_Zillow.csv", chart_format="bokeh", depVar="price")
# Out:
# Shape of your Data Set loaded: (4943, 25)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  14
#     Number of Integer-Categorical Columns =  2
#     Number of String-Categorical Columns =  2
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  6
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     24 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
#
# ################ Regression problem #####################
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="d4e1584b-8176-457b-b272-ec50a65f9a3b" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"890f5cd1-1eb3-4473-9610-a820186d71f4":{"version":"3.5.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"34d63e2f132f4934b60400f480dda7bd","client_comm_id":"8fdd8d61f78c457d82cc2321e7f0619f"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1"},{"type":"model","name":"JSComponent1"},{"ty ...
#   var render_items = [{"docid":"890f5cd1-1eb3-4473-9610-a820186d71f4","roots":{"p1002":"d4e1584b-8176-457b-b272-ec50a65f9a3b"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'1c2f266b-0a6a-4282-97b2-43bd483a569b': {'version…
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'a1dda831-f68c-4f3d-8d63-5587ad2b312d': {'version…
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'ea2ad8c8-d457-48b1-b250-85859e39eb01': {'version…
# BokehModel(combine_events=True, render_bundle={'docs_json': {'931ddf53-24e5-47a5-b671-597b8bc9a7c4': {'version…
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'155cd76a-e2fa-4bca-92b0-20f28c8a7857': {'version…
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'59160ce2-ec05-4536-9ef5-6ed804f2216f': {'version…
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# No date vars could be found in data set
# BokehModel(combine_events=True, render_bundle={'docs_json': {'58fd4c10-96b5-4cab-a316-9b7b15ee8c6c': {'version…
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'9968bfa1-a64c-4351-a7cb-8e56101b104b': {'version…
# Time to run AutoViz (in seconds) = 5

# %% [markdown]
# <b>SweetViz</b>

# %%
report=sv.analyze(df)
report.show_html('sv_Zillow.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report sv_Zillow.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# <b>Phik-Matrix</b>

# %%
# compute phik-matrix values
phik_matrix = df.phik_matrix()

phik_matrix
# Out:
# interval columns not set, guessing: ['longitude', 'countyFIPS', 'monthlyHoaFee', 'annualHomeownersInsurance', 'yearBuilt', 'latitude', 'rentZestimate', 'zestimateLowPercent', 'timeOnZillow', 'zestimate', 'livingArea', 'zipcode', 'propertyTaxRate', 'bathrooms', 'bedrooms', 'price', 'zestimateHighPercent', 'homeType_APARTMENT', 'homeType_CONDO', 'homeType_LOT', 'homeType_MANUFACTURED', 'homeType_MULTI_FAMILY', 'homeType_SINGLE_FAMILY']
#                            longitude  countyFIPS  monthlyHoaFee  \
# longitude                  1.000000    0.748223        0.0
# countyFIPS                 0.748223    1.000000        0.0
# monthlyHoaFee              0.000000    0.000000        1.0
# annualHomeownersInsurance  0.337465    0.170004        0.0
# state                      0.993330    0.971783        0.0
# yearBuilt                  0.469439    0.715197        0.0
# latitude                   0.920371    0.795448        0.0
# rentZestimate              0.161613    0.206545        0.0
# city                       0.999255    0.997363        0.0
# zestimateLowPercent        0.201773    0.285341        0.0
# timeOnZillow               0.187069    0.123139        0.0
# zestimate                  0.345138    0.187602        0.0
# livingArea                 0.314912    0.000000        0.0
# zipcode                    0.926339    0.924198        0.0
# propertyTaxRate            0.810424    0.884518        0.0
# bathrooms                  0.294034    0.000000        0.0
# bedrooms                   0.435881    0.000000        0.0
# price                      0.337447    0.169963        0.0
# zestimateHighPercent       0.207476    0.270195        0.0
# homeType_APARTMENT         0.000000    0.000000        0.0
# homeType_CONDO             0.000000    0.000000        0.0
# homeType_LOT               0.000000    0.000000        0.0
# homeType_MANUFACTURED      0.249639    0.172643        0.0
# homeType_MULTI_FAMILY      0.010560    0.000000        0.0
# homeType_SINGLE_FAMILY     0.044140    0.023036        0.0
#
#                            annualHomeownersInsurance    state   yearBuilt  \
# longitude                          0.337465           0.993330  0.469439
# countyFIPS                         0.170004           0.971783  0.715197
# monthlyHoaFee                      0.000000           0.000000  0.000000
# annualHomeownersInsurance          1.000000           0.531775  0.219157
# state                              0.531775           1.000000  0.795375
# yearBuilt                          0.219157           0.795375  1.000000
# latitude                           0.227254           0.977539  0.477871
# rentZestimate                      0.740431           0.329623  0.199570
# city                               0.781691           0.999691  0.894899
# zestimateLowPercent                0.391305           0.512700  0.423695
# timeOnZillow                       0.000000           0.133082  0.054350
# zestimate                          0.995520           0.557059  0.216455
# livingArea                         0.771645           0.245103  0.194740
# zipcode                            0.167506           0.995125  0.701346
# propertyTaxRate                    0.291274           0.957428  0.837613
# bathrooms                          0.768607           0.365653  0.101926
# bedrooms                           0.676196           0.350956  0.192979
# price                              1.000000           0.531753  0.219116
# zestimateHighPercent               0.278158           0.382022  0.382972
# homeType_APARTMENT                 0.082017           0.000000  0.032404
# homeType_CONDO                     0.664526           0.000000  0.296259
# homeType_LOT                       0.000000           0.000000  0.113124
# homeType_MANUFACTURED              0.084225           0.486930  0.000000
# homeType_MULTI_FAMILY              0.156903           0.059472  0.190117
# homeType_SINGLE_FAMILY             0.520473           0.059688  0.212800
#
#                            latitude  rentZestimate    city    \
# longitude                  0.920371    0.161613     0.999255
# countyFIPS                 0.795448    0.206545     0.997363
# monthlyHoaFee              0.000000    0.000000     0.000000
# annualHomeownersInsurance  0.227254    0.740431     0.781691
# state                      0.977539    0.329623     0.999691
# yearBuilt                  0.477871    0.199570     0.894899
# latitude                   1.000000    0.253810     0.998894
# rentZestimate              0.253810    1.000000     0.755909
# city                       0.998894    0.755909     1.000000
# zestimateLowPercent        0.217759    0.262271     0.650938
# timeOnZillow               0.192754    0.011540     0.099648
# zestimate                  0.235544    0.733505     0.791146
# livingArea                 0.165355    0.702457     0.595560
# zipcode                    0.881081    0.239770     0.999494
# propertyTaxRate            0.796685    0.215224     0.998952
# bathrooms                  0.158979    0.415323     0.756987
# bedrooms                   0.240569    0.341677     0.737763
# price                      0.227221    0.740294     0.781685
# zestimateHighPercent       0.201764    0.457521     0.656152
# homeType_APARTMENT         0.000000    0.200794     0.000000
# homeType_CONDO             0.019973    0.718866     0.000000
# homeType_LOT               0.000000    0.067246     0.000000
# homeType_MANUFACTURED      0.213497    0.037903     0.728107
# homeType_MULTI_FAMILY      0.000000    0.193297     0.115865
# homeType_SINGLE_FAMILY     0.028326    0.635820     0.090723
#
#                            zestimateLowPercent  timeOnZillow  zestimate  \
# longitude                       0.201773          0.187069    0.345138
# countyFIPS                      0.285341          0.123139    0.187602
# monthlyHoaFee                   0.000000          0.000000    0.000000
# annualHomeownersInsurance       0.391305          0.000000    0.995520
# state                           0.512700          0.133082    0.557059
# yearBuilt                       0.423695          0.054350    0.216455
# latitude                        0.217759          0.192754    0.235544
# rentZestimate                   0.262271          0.011540    0.733505
# city                            0.650938          0.099648    0.791146
# zestimateLowPercent             1.000000          0.195482    0.392579
# timeOnZillow                    0.195482          1.000000    0.000000
# zestimate                       0.392579          0.000000    1.000000
# livingArea                      0.547979          0.029955    0.785681
# zipcode                         0.275093          0.127153    0.187930
# propertyTaxRate                 0.239837          0.122823    0.299728
# bathrooms                       0.188998          0.000000    0.766765
# bedrooms                        0.315929          0.000000    0.683696
# price                           0.390863          0.000000    0.995527
# zestimateHighPercent            0.923651          0.076020    0.277147
# homeType_APARTMENT              0.166919          0.022429    0.042753
# homeType_CONDO                  0.173331          0.029316    0.536773
# homeType_LOT                    0.571268          0.000000    0.000000
# homeType_MANUFACTURED           0.283320          0.010500    0.051332
# homeType_MULTI_FAMILY           0.120863          0.037055    0.170309
# homeType_SINGLE_FAMILY          0.203483          0.059516    0.383011
#
#                            livingArea   zipcode  propertyTaxRate  bathrooms  \
# longitude                   0.314912   0.926339     0.810424      0.294034
# countyFIPS                  0.000000   0.924198     0.884518      0.000000
# monthlyHoaFee               0.000000   0.000000     0.000000      0.000000
# annualHomeownersInsurance   0.771645   0.167506     0.291274      0.768607
# state                       0.245103   0.995125     0.957428      0.365653
# yearBuilt                   0.194740   0.701346     0.837613      0.101926
# latitude                    0.165355   0.881081     0.796685      0.158979
# rentZestimate               0.702457   0.239770     0.215224      0.415323
# city                        0.595560   0.999494     0.998952      0.756987
# zestimateLowPercent         0.547979   0.275093     0.239837      0.188998
# timeOnZillow                0.029955   0.127153     0.122823      0.000000
# zestimate                   0.785681   0.187930     0.299728      0.766765
# livingArea                  1.000000   0.000000     0.173078      0.717396
# zipcode                     0.000000   1.000000     0.895236      0.000000
# propertyTaxRate             0.173078   0.895236     1.000000      0.253630
# bathrooms                   0.717396   0.000000     0.253630      1.000000
# bedrooms                    0.863763   0.000000     0.240285      0.900319
# price                       0.771756   0.167464     0.291252      0.768607
# zestimateHighPercent        0.544645   0.243802     0.249862      0.189711
# homeType_APARTMENT          0.097063   0.000000     0.000000      0.000000
# homeType_CONDO              0.419802   0.000000     0.052643      0.119463
# homeType_LOT                0.248000   0.000000     0.000000      0.000000
# homeType_MANUFACTURED       0.024659   0.215503     0.309819      0.000000
# homeType_MULTI_FAMILY       0.218425   0.000000     0.074966      0.328850
# homeType_SINGLE_FAMILY      0.290823   0.013744     0.059162      0.077865
#
#                            bedrooms    price   zestimateHighPercent  \
# longitude                  0.435881  0.337447        0.207476
# countyFIPS                 0.000000  0.169963        0.270195
# monthlyHoaFee              0.000000  0.000000        0.000000
# annualHomeownersInsurance  0.676196  1.000000        0.278158
# state                      0.350956  0.531753        0.382022
# yearBuilt                  0.192979  0.219116        0.382972
# latitude                   0.240569  0.227221        0.201764
# rentZestimate              0.341677  0.740294        0.457521
# city                       0.737763  0.781685        0.656152
# zestimateLowPercent        0.315929  0.390863        0.923651
# timeOnZillow               0.000000  0.000000        0.076020
# zestimate                  0.683696  0.995527        0.277147
# livingArea                 0.863763  0.771756        0.544645
# zipcode                    0.000000  0.167464        0.243802
# propertyTaxRate            0.240285  0.291252        0.249862
# bathrooms                  0.900319  0.768607        0.189711
# bedrooms                   1.000000  0.676241        0.302439
# price                      0.676241  1.000000        0.277882
# zestimateHighPercent       0.302439  0.277882        1.000000
# homeType_APARTMENT         0.053398  0.081837        0.189445
# homeType_CONDO             0.270684  0.663667        0.123910
# homeType_LOT               0.000000  0.000000        0.772496
# homeType_MANUFACTURED      0.000000  0.084096        0.349353
# homeType_MULTI_FAMILY      0.389955  0.157039        0.103543
# homeType_SINGLE_FAMILY     0.153457  0.519503        0.190712
#
#                            homeType_APARTMENT  homeType_CONDO  homeType_LOT  \
# longitude                       0.000000          0.000000       0.000000
# countyFIPS                      0.000000          0.000000       0.000000
# monthlyHoaFee                   0.000000          0.000000       0.000000
# annualHomeownersInsurance       0.082017          0.664526       0.000000
# state                           0.000000          0.000000       0.000000
# yearBuilt                       0.032404          0.296259       0.113124
# latitude                        0.000000          0.019973       0.000000
# rentZestimate                   0.200794          0.718866       0.067246
# city                            0.000000          0.000000       0.000000
# zestimateLowPercent             0.166919          0.173331       0.571268
# timeOnZillow                    0.022429          0.029316       0.000000
# zestimate                       0.042753          0.536773       0.000000
# livingArea                      0.097063          0.419802       0.248000
# zipcode                         0.000000          0.000000       0.000000
# propertyTaxRate                 0.000000          0.052643       0.000000
# bathrooms                       0.000000          0.119463       0.000000
# bedrooms                        0.053398          0.270684       0.000000
# price                           0.081837          0.663667       0.000000
# zestimateHighPercent            0.189445          0.123910       0.772496
# homeType_APARTMENT              1.000000          0.053825       0.000000
# homeType_CONDO                  0.053825          1.000000       0.000000
# homeType_LOT                    0.000000          0.000000       1.000000
# homeType_MANUFACTURED           0.000000          0.000000       0.000000
# homeType_MULTI_FAMILY           0.031604          0.196097       0.000000
# homeType_SINGLE_FAMILY          0.238220          0.888790       0.084989
#
#                            homeType_MANUFACTURED  homeType_MULTI_FAMILY  \
# longitude                        0.249639               0.010560
# countyFIPS                       0.172643               0.000000
# monthlyHoaFee                    0.000000               0.000000
# annualHomeownersInsurance        0.084225               0.156903
# state                            0.486930               0.059472
# yearBuilt                        0.000000               0.190117
# latitude                         0.213497               0.000000
# rentZestimate                    0.037903               0.193297
# city                             0.728107               0.115865
# zestimateLowPercent              0.283320               0.120863
# timeOnZillow                     0.010500               0.037055
# zestimate                        0.051332               0.170309
# livingArea                       0.024659               0.218425
# zipcode                          0.215503               0.000000
# propertyTaxRate                  0.309819               0.074966
# bathrooms                        0.000000               0.328850
# bedrooms                         0.000000               0.389955
# price                            0.084096               0.157039
# zestimateHighPercent             0.349353               0.103543
# homeType_APARTMENT               0.000000               0.031604
# homeType_CONDO                   0.000000               0.196097
# homeType_LOT                     0.000000               0.000000
# homeType_MANUFACTURED            1.000000               0.000000
# homeType_MULTI_FAMILY            0.000000               1.000000
# homeType_SINGLE_FAMILY           0.112242               0.701941
#
#                            homeType_SINGLE_FAMILY
# longitude                         0.044140
# countyFIPS                        0.023036
# monthlyHoaFee                     0.000000
# annualHomeownersInsurance         0.520473
# state                             0.059688
# yearBuilt                         0.212800
# latitude                          0.028326
# rentZestimate                     0.635820
# city                              0.090723
# zestimateLowPercent               0.203483
# timeOnZillow                      0.059516
# zestimate                         0.383011
# livingArea                        0.290823
# zipcode                           0.013744
# propertyTaxRate                   0.059162
# bathrooms                         0.077865
# bedrooms                          0.153457
# price                             0.519503
# zestimateHighPercent              0.190712
# homeType_APARTMENT                0.238220
# homeType_CONDO                    0.888790
# homeType_LOT                      0.084989
# homeType_MANUFACTURED             0.112242
# homeType_MULTI_FAMILY             0.701941
# homeType_SINGLE_FAMILY            1.000000

# %% [markdown]
# <b>Data Prep</b>
# <p> is done in Python 3.9 you can see the report in the html folder</p>

# %% [markdown]
# <h3>X/Y Tets</h3>

# %% [markdown]
# <b>X</b>

# %%
# everything else except the target variable
X = df.drop(["price","state","city","zestimate","annualHomeownersInsurance"], axis=1)
#this got revisited after the correlation test, removed the 1 correlations

# %%
X.columns
# Out:
# Index(['longitude', 'countyFIPS', 'monthlyHoaFee', 'yearBuilt', 'latitude',
#        'rentZestimate', 'zestimateLowPercent', 'timeOnZillow', 'livingArea',
#        'zipcode', 'propertyTaxRate', 'bathrooms', 'bedrooms',
#        'zestimateHighPercent', 'homeType_APARTMENT', 'homeType_CONDO',
#        'homeType_LOT', 'homeType_MANUFACTURED', 'homeType_MULTI_FAMILY',
#        'homeType_SINGLE_FAMILY'],
#       dtype='object')

# %% [markdown]
# <b>Y Regression</b>

# %%
# have only the target variable here (dependent variable)
y = df['price']

# %%
# have only the target variable here (dependent variable)
# y_temp = df['price_range']

# since we are doing classification, we have to process our target values with an encoder
# and convert them into a categorical TensorFlow/Keras -format 
# le = LabelEncoder()
# y_enc = le.fit_transform(y_temp)

# Converting the label into a matrix form
# y = tf.keras.utils.to_categorical(y_enc)

# %% [markdown]
# <b>Shap</b>

# %%
# %matplotlib inline

# %%
# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Train model
model = RandomForestRegressor()
model.fit(X_train, y_train)

# Initialize SHAP explainer
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_test)

# Plot SHAP summary
shap.summary_plot(shap_values, X_test, show=True)

# Feature importance
importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': np.mean(np.abs(shap_values), axis=0)
})
print("Feature Importances using SHAP:")
print(importance)
# Out:
# Feature Importances using SHAP:
#            Feature           Importance
# 0                longitude   6052.775328
# 1               countyFIPS     86.560933
# 2            monthlyHoaFee   2438.981125
# 3                yearBuilt   4792.796208
# 4                 latitude   6931.617536
# 5            rentZestimate  30650.412580
# 6      zestimateLowPercent   3675.083819
# 7             timeOnZillow   1353.158759
# 8               livingArea  87039.812732
# 9                  zipcode   2278.187482
# 10         propertyTaxRate    124.465677
# 11               bathrooms   1284.844994
# 12                bedrooms   1023.289121
# 13    zestimateHighPercent   3134.407266
# 14      homeType_APARTMENT     73.383353
# 15          homeType_CONDO  14831.840209
# 16            homeType_LOT     25.332877
# 17   homeType_MANUFACTURED    134.806817
# 18   homeType_MULTI_FAMILY    450.075700
# 19  homeType_SINGLE_FAMILY    486.759734

# %%
# pip install skfeature-chappers
from skfeature.function.similarity_based import fisher_score

# get the fisher's score rankings 
ranks = fisher_score.fisher_score(X.values, y.values)

# create a pandas DataFrame for easier interpretation
feat_importances = pd.Series(ranks, X.columns)
feat_importances.plot(kind='barh')
# Out:
# <Axes: >
